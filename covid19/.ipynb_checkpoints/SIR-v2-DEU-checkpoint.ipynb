# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Definition of the model

# %%
# The SIR model differential equations.
def deriv(y, t, N, gamma,beta1,beta2,t_tresh=22):
    S,I,R = y

    if t<=t_tresh:
        B=beta1
    else:
        B=beta1*np.exp(-(t-t_tresh)/beta2)
    
    dSdt = -(B*I/N)*S 
    dIdt = (B*S/N)*I - gamma*I 
    dRdt = gamma*I 
    
    return dSdt, dIdt, dRdt

# %% [markdown]
# ### Integration of the differential equations

# %%
def time_evo(N,beta1,beta2,gamma,death_rate,t_tresh=22,I0=1,R0=0,t=np.arange(0,365)):
    # Definition of the initial conditions
    # I0 and R0 denotes the number of initial infected people (I0) 
    # and the number of people that recovered and are immunized (R0)
    
    # t ise the timegrid
    
    S0=N-I0-R0  # number of people that can still contract the virus
    
    # Initial conditions vector
    y0 = S0, I0, R0

    # Integrate the SIR equations over the time grid, t.
    ret = odeint(deriv, y0, t, args=(N,gamma,beta1,beta2,t_tresh))
    S, I, R = np.transpose(ret)
    
    return (t,S,I,(1-death_rate/100)*R,R*death_rate/100)

# %% [markdown]
# ### Show the result

# %%
fin_result=time_evo(1000,0.3,10000,0.1,0)

t=fin_result[0]
s_vec=fin_result[1]
i_vec=fin_result[2]
r_vec=fin_result[3]
m_vec=fin_result[4]

plt.plot(t, s_vec, 'b', label='Susceptible')
plt.plot(t, i_vec, 'r', label='Infected')
plt.plot(t, r_vec, 'g', label='Recovered with immunity')
plt.plot(t, m_vec, 'k', label='Deaths')
#plt.plot(t, i_vec+r_vec, color='orange',linestyle='--', label='Infected + Recovered')
plt.legend()
#plt.yscale('log')
#plt.ylim(0.5,3000)
plt.xlim(0,100)
plt.xlabel('Number of days')
plt.ylabel('Number of people')
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.show()

#print(s_vec+i_vec+r_vec+m_vec)

# %% [markdown]
# ### Load German data

# %%
dataDEU=pd.read_csv('dataDEU.txt')

xdata=dataDEU['Time']
ydata=dataDEU['Infected']
ydata_death=dataDEU['Deaths']
ydata_rec=dataDEU['Recovered']

dataITA=pd.read_csv('dataITA.txt')
xdata_ITA=dataITA['Time']
ydata_ITA=dataITA['Infected']
ydata_death_ITA=dataITA['Deaths']
ydata_rec_ITA=dataITA['Recovered']

dataDEU.iloc[-1,:]
# Out:
# Time            33
# Infected     37323
# Deaths         206
# Recovered        0
# Name: 33, dtype: int64

# %%
plt.errorbar(xdata,ydata,np.sqrt(ydata),linestyle='None',label='Contaminated',marker='s')
plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),linestyle='None',label='Deaths',marker='s')
plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),linestyle='None',label='Recovered',marker='s')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar'])
plt.yscale('log')
plt.xlabel('Data')
plt.ylabel('Counter')
plt.xlim(0,21)
plt.legend()
plt.savefig('DataDEUonly.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(5,8))
plt.subplot(2,1,1)
plt.errorbar(xdata,ydata,np.sqrt(ydata),linestyle='None',marker='s',label='Germany')
plt.errorbar(xdata_ITA,ydata_ITA,np.sqrt(ydata_ITA),marker='s',linestyle='None',label='Italy')
#plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),linestyle='None',label='Deaths',marker='s')
#plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),linestyle='None',label='Recovered',marker='s')
plt.yscale('log')
plt.xlabel('Data')
plt.ylabel('Counter')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar'])
plt.xlim(-1,22)
#plt.ylim(30,3000)
plt.legend()
plt.subplot(2,1,2)
plt.errorbar(xdata,ydata,np.sqrt(ydata),linestyle='None',marker='s',label='Germany')
plt.errorbar(xdata_ITA+9,ydata_ITA,np.sqrt(ydata_ITA),marker='s',linestyle='None',label='Italy')
#plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),linestyle='None',label='Deaths',marker='s')
#plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),linestyle='None',label='Recovered',marker='s')
plt.yscale('log')
plt.xlabel('Data (+9 days of shift)')
plt.ylabel('Counter')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar'])
plt.xlim(-1,40)
plt.legend()
plt.savefig('comparison_ITADE.png',dpi=300)
plt.show()

# %%
plt.errorbar(xdata,ydata,np.sqrt(ydata),label='Germany')
plt.errorbar(xdata_ITA+8,ydata_ITA,np.sqrt(ydata_ITA),linestyle='--',label='Italy')
#plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),linestyle='None',label='Deaths',marker='s')
#plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),linestyle='None',label='Recovered',marker='s')
plt.yscale('log')
plt.xlabel('Data (+8 days of shift)')
plt.ylabel('Counter')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar'])
plt.xlim(-1,36)
plt.legend()
plt.savefig('comparison_ITADE_v2.png',dpi=300)
plt.show()

# %% [markdown]
# ### comparison between model and data

# %%
fin_result=time_evo(83*10**6,0.41,25,1/14,0.4,t_tresh=15,I0=13,t=np.arange(0,720))

t=fin_result[0]
s_vec=fin_result[1]
i_vec=fin_result[2]
r_vec=fin_result[3]
m_vec=fin_result[4]

ydata_inf=ydata-ydata_death-ydata_rec

plt.errorbar(xdata,ydata_inf,np.sqrt(ydata-ydata_rec),color='red',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),color='black',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),color='green',linestyle='None',marker='s')
plt.plot(t, s_vec, 'b--', label='Susceptible')
plt.plot(t, i_vec/3, 'r--', label='Infected/3')
#plt.plot(t, r_vec, 'g--', label='Recovered with immunity')
plt.plot(t, m_vec, 'k--', label='Deaths')
plt.yscale('log')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr','10 Apr'])
plt.xlim(0,50)
plt.ylim(1,10**5)
plt.xlabel('Number of days from the beginning')
plt.ylabel('Counter')
plt.legend(loc=4)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.savefig('sirdatacomp_DEU.png',dpi=300)
plt.show()

# %%
# percentage variation of the contaminted people, compared to the previous day


# data increment
incremento=[]

for i in range(3,len(ydata)):
    incremento.append(ydata[i]/ydata[i-1])
 

# sir increment
incr_SIR=[]

for i in range(len(i_vec)-1):
    incr_SIR.append(i_vec[i+1]/i_vec[i])

plt.step(xdata[xdata>=3],incremento,label='Data')
plt.step(t[1:],incr_SIR,label='Model')
plt.xlabel('Days from the beginning')
plt.ylabel('Variation')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr'])
plt.xlim(0,50)
plt.ylim(0.9,2)
plt.legend()
plt.savefig('first_derivative_SIR_DEU.png',dpi=300)
plt.show()

# %% [markdown]
# ## predictions

# %%
plt.errorbar(xdata,ydata-ydata_rec,np.sqrt(ydata-ydata_rec),color='red',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),color='black',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),color='green',linestyle='None',marker='s')
plt.plot(t, s_vec, 'b--', label='Susceptible')
plt.plot(t, i_vec/3, 'r--', label='Infected/3')
plt.plot(t, r_vec, 'g--', label='Recovered with immunity')
plt.plot(t, m_vec, 'k--', label='Deaths')
plt.yscale('log')
plt.xticks(np.arange(9,210,30),['Mar','Apr','May','Jun','Jul','Aug','Sep'])
plt.xlim(0,180)
plt.ylim(1,0.2*10**7)
plt.xlabel('Number of days from the beginning')
plt.ylabel('Counter')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.savefig('sirdatacomp_prediction_DEU.png',dpi=300)
plt.show()

# %%
### combined plot

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.errorbar(xdata,ydata_inf,np.sqrt(ydata-ydata_rec),color='red',linestyle='None',marker='s',label='Infected')
plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),color='black',linestyle='None',marker='s',label='Deaths')
plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),color='green',linestyle='None',marker='s',label='Recovered with immunity')
plt.plot(t, s_vec, 'b--')
plt.plot(t, i_vec/3, 'r--',label='Infected/3 (model)')
#plt.plot(t, r_vec, 'g--', label='Recovered with immunity')
plt.plot(t, m_vec, 'k--',label='Deaths (model)')
plt.yscale('log')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr'])
plt.xlim(0,45)
plt.ylim(1,10**5)
plt.xlabel('Data')
plt.ylabel('Counter')
plt.legend(loc=4)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.subplot(1,3,2)
plt.step(xdata[xdata>=3],incremento,label='Data')
plt.step(t[1:],incr_SIR,label='Model')
plt.xlabel('Data')
plt.ylabel('Variation')
plt.xticks(np.arange(0,50,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr'])
plt.xlim(0,45)
plt.ylim(0.9,2)
plt.legend()
plt.subplot(1,3,3)
plt.errorbar(xdata,ydata_inf,np.sqrt(ydata-ydata_rec),color='red',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_death,np.sqrt(ydata_death),color='black',linestyle='None',marker='s')
plt.errorbar(xdata,ydata_rec,np.sqrt(ydata_rec),color='green',linestyle='None',marker='s')
#plt.plot(t, s_vec, 'b--', label='Susceptible')
plt.plot(t, i_vec/3, 'r--', label='Infected/3')
plt.plot(t, r_vec, 'g--', label='Recovered with immunity')
plt.plot(t, m_vec, 'k--', label='Deaths')
plt.yscale('log')
plt.xticks(np.arange(9,210,30),['Mar','Apr','May','Jun','Jul','Aug','Sep'])
plt.xlim(0,180)
plt.ylim(1,0.7*10**7)
plt.xlabel('Data')
plt.ylabel('Counter')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('combined_SIR_DEU.png',dpi=300)
plt.show()

# %%
print('Total deaths ',int(m_vec[-1]))
print('Total infected ',int(m_vec[-1]+r_vec[-1]))
print('Infected today ',np.array(ydata_inf)[-1])
print('Maximum infected ',int(i_vec.max()/3))
print('Maximum infected (hospitalized)',int(i_vec.max()/3*20/100))
print('Maximum intensive care',int(i_vec.max()/3*7/100))
# Out:
# Total deaths  5975
# Total infected  1493983
# Infected today  37117
# Maximum infected  142456
# Maximum infected (hospitalized) 28491
# Maximum intensive care 9971

# %%
# Out:
# 37117

# %%
modello_check=i_vec[0:len(ydata)]/3
modello_check=modello_check[8:]

data_check=(ydata-ydata_rec)
data_check=data_check[8:]

accuracy=round(np.mean(np.abs((data_check-modello_check))/data_check)*100,2)

print('The accuracy of the model on past data is ',accuracy,'%')
# Out:
# The accuracy of the model on past data is  13.39 %
