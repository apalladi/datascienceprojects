# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.integrate import odeint
import time as pctime

# %% [markdown]
# # load national data

# %%
# dati cumulativi

data = pd.read_csv('https://github.com/pcm-dpc/COVID-19/raw/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv')
xdata=pd.to_numeric(range(data.shape[0]))
ydata=data['totale_casi']
ydata_death=data['deceduti']
ydata_rec=data['dimessi_guariti']
ydata_tamponi=data['tamponi']
ydata_ospedale=np.array(data['totale_ospedalizzati'])
ydata_ricoverati=np.array(data['ricoverati_con_sintomi'])

ydata_death=np.array(ydata_death)
ydata_rec=np.array(ydata_rec)
ydata=np.array(ydata)

ydata_inf=np.array(ydata-ydata_rec-ydata_death)

ydata_terint=np.array(data['terapia_intensiva'])

print(data.iloc[-1,:])

data.head()
# Out:
# data                            2020-09-03T17:00:00
# stato                                           ITA
# ricoverati_con_sintomi                         1505
# terapia_intensiva                               120
# totale_ospedalizzati                           1625
# isolamento_domiciliare                        27290
# totale_positivi                               28915
# variazione_totale_positivi                     1098
# nuovi_positivi                                 1397
# dimessi_guariti                              208490
# deceduti                                      35507
# casi_da_sospetto_diagnostico                 230950
# casi_da_screening                             41962
# totale_casi                                  272912
# tamponi                                     8921658
# casi_testati                            5.34215e+06
# note                                            NaN
# Name: 192, dtype: object
#                   data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0  2020-02-24T18:00:00   ITA                     101                 26
# 1  2020-02-25T18:00:00   ITA                     114                 35
# 2  2020-02-26T18:00:00   ITA                     128                 36
# 3  2020-02-27T18:00:00   ITA                     248                 56
# 4  2020-02-28T18:00:00   ITA                     345                 64
#
#    totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 0                   127                      94              221
# 1                   150                     162              311
# 2                   164                     221              385
# 3                   304                     284              588
# 4                   409                     412              821
#
#    variazione_totale_positivi  nuovi_positivi  dimessi_guariti  deceduti  \
# 0                           0             221                1         7
# 1                          90              93                1        10
# 2                          74              78                3        12
# 3                         203             250               45        17
# 4                         233             238               46        21
#
#    casi_da_sospetto_diagnostico  casi_da_screening  totale_casi  tamponi  \
# 0                           NaN                NaN          229     4324
# 1                           NaN                NaN          322     8623
# 2                           NaN                NaN          400     9587
# 3                           NaN                NaN          650    12014
# 4                           NaN                NaN          888    15695
#
#    casi_testati note
# 0           NaN  NaN
# 1           NaN  NaN
# 2           NaN  NaN
# 3           NaN  NaN
# 4           NaN  NaN

# %%
data.iloc[-1,:]
# Out:
# data                            2020-09-03T17:00:00
# stato                                           ITA
# ricoverati_con_sintomi                         1505
# terapia_intensiva                               120
# totale_ospedalizzati                           1625
# isolamento_domiciliare                        27290
# totale_positivi                               28915
# variazione_totale_positivi                     1098
# nuovi_positivi                                 1397
# dimessi_guariti                              208490
# deceduti                                      35507
# casi_da_sospetto_diagnostico                 230950
# casi_da_screening                             41962
# totale_casi                                  272912
# tamponi                                     8921658
# casi_testati                            5.34215e+06
# note                                            NaN
# Name: 192, dtype: object

# %%
print('fatality rate ',ydata_death[-1]/(ydata_rec[-1]+ydata_death[-1]))

print('fatality rate ', ydata_death[-1]/(ydata[-1]))
# Out:
# fatality rate  0.1455222810116518
# fatality rate  0.13010420941548925

# %%
ydata_diff=np.diff(ydata)

ydata_diff=np.append(0,ydata_diff)
xdata_diff=np.arange(0,len(ydata_diff))

# %%
ymorti=np.diff(ydata_death)
ymorti[172]=ymorti[172]-154   # ricalcolo morti Emilia-Romagna

ymorti=np.append(0,ymorti)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(xdata_diff,ydata_diff,alpha=0.5,label='Nuovi casi giornalieri')
plt.plot(ydata_ricoverati/10,label='Ricoverati con sintomi (/10)',color='green')
plt.plot(ydata_terint,label='Ricoverati in terapia intensiva',color='red')
plt.grid()
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago','31 Ago'],rotation=70)
plt.xlim(0,len(ydata_terint))
plt.ylim(0,6500)
plt.legend()
plt.subplot(1,3,2)
plt.bar(xdata_diff,ymorti,label='Decessi',color='black')
plt.ylim(0,1000)
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago','31 Ago'],rotation=70)
plt.xlim(0,len(ymorti))
plt.grid()
plt.legend()
plt.subplot(1,3,3)
plt.plot(ydata_terint,color='red',label='Ricoverati in terapia intensiva')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago','31 Ago'],rotation=70)
plt.ylim(0,200)
plt.xlim(110,len(ydata_terint))
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('output3/ricoverati_decessi.png',dpi=300)
plt.show()

# %%
plt.plot(ydata_terint,color='red',label='Ricoverati in terapia intensiva')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago','31 Ago'],rotation=70)
plt.ylim(0,200)
plt.xlim(110,len(ydata_terint))
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('output3/terint_plot.png',dpi=300)
plt.show()

# %%
print(data.iloc[127,0])

print(data.iloc[158,0])

print(ydata_death[158]-ydata_death[127])

print(ydata_death[-1]-ydata_death[158])
# Out:
# 2020-06-30T17:00:00
# 2020-07-31T17:00:00
# 374
# 366

# %%
# dati differenziali

ydata_incr=[]
ydata_death_incr=[]
ydata_rec_incr=[]

for i in range(len(ydata)-1):
    ydata_incr.append(ydata[i+1]-ydata[i])
    ydata_death_incr.append(ydata_death[i+1]-ydata_death[i])
    ydata_rec_incr.append(ydata_rec[i+1]-ydata_rec[i])

# %%
# cumulative

plt.plot(np.arange(len(ydata)),ydata,label='Total')
plt.plot(np.arange(len(ydata)),ydata_rec,label='Recovered')
plt.plot(np.arange(len(ydata)),ydata_death,label='Deaths')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,len(ydata))
plt.ylabel('Number')
plt.title('Cumulative functions')
plt.legend()
plt.tight_layout()
plt.savefig('output3/dataonly.png',dpi=300)
plt.show()

# %%
np.diff(ydata_tamponi)
# Out:
# array([ 4299,   964,  2427,  3681,  2966,  2466,  2218,  2511,  3981,
#         2525,  3997,  5703,  7875,  3889,  6935, 12393, 12857, 11477,
#        11682, 15729, 13063, 10695, 16884, 17236, 24109, 26336, 25180,
#        17066, 21496, 27481, 36615, 33019, 35447, 24504, 23329, 29609,
#        34455, 39809, 38617, 37375, 34237, 30271, 33713, 51680, 46244,
#        53495, 56609, 46720, 36717, 26779, 43715, 60999, 65705, 61725,
#        50708, 41483, 52126, 63101, 66658, 62447, 65387, 49916, 32003,
#        57272, 63827, 68456, 74208, 55412, 44935, 37631, 55263, 64263,
#        70359, 63775, 69171, 51678, 40740, 67003, 61973, 71876, 68176,
#        69179, 60101, 36406, 63158, 67195, 71679, 75380, 72410, 55824,
#        35241, 57674, 67324, 75893, 72135, 69342, 54118, 31394, 52159,
#        37299, 49953, 65028, 72485, 49478, 27112, 55003, 62699, 62472,
#        70620, 49750, 56527, 28107, 46882, 77701, 58154, 57541, 54722,
#        40545, 28972, 40485, 53266, 56061, 52768, 61351, 37346, 27218,
#        48273, 55366, 53243, 50096, 52011, 37462, 22166, 43219, 50443,
#        52552, 47953, 45931, 38259, 23933, 41867, 48449, 50432, 50767,
#        48265, 35525, 24253, 43110, 49318, 60311, 53334, 51671, 40526,
#        25551, 48170, 56018, 61858, 60944, 60383, 43269, 24036, 43788,
#        56451, 58673, 59196, 53298, 37637, 26432, 40642, 52658, 51188,
#        46723, 53123, 36807, 30666, 53976, 71095, 77442, 71996, 77674,
#        67371, 45914, 72341, 93529, 94024, 97065, 99108, 76723, 58518])

# %%
# incremental

plt.bar(np.arange(len(ydata_incr)),ydata_incr,label='New cases')
plt.bar(np.arange(len(ydata_incr)),ydata_rec_incr,label='New recovered')
plt.bar(np.arange(len(ydata_incr)),ydata_death_incr,label='New deaths',alpha=0.7)
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago'],rotation=90)
plt.xlim(-1,len(ydata_incr))
#plt.ylim(0,2000)
plt.ylabel('Number')
plt.title('Daily cases')
plt.legend()
plt.savefig('output3/dataonly_deriv.png',dpi=300)
plt.show()

# %%
'''
# dati differenziali

ydata_incr2=[]
ydata_death_incr2=[]
ydata_rec_incr2=[]

tm=5

for i in range(int(len(ydata)/tm)):
    ydata_incr2.append(ydata[tm*i+tm]-ydata[tm*i])
    ydata_death_incr2.append(ydata_death[tm*i+tm]-ydata_death[tm*i])
    ydata_rec_incr2.append(ydata_rec[tm*i+tm]-ydata_rec[tm*i])
    
ydata_incr2=np.array(ydata_incr2)
ydata_death_incr2=np.array(ydata_death_incr2)
ydata_rec_incr2=np.array(ydata_rec_incr2)
'''
# Out:
# '\n# dati differenziali\n\nydata_incr2=[]\nydata_death_incr2=[]\nydata_rec_incr2=[]\n\ntm=5\n\nfor i in range(int(len(ydata)/tm)):\n    ydata_incr2.append(ydata[tm*i+tm]-ydata[tm*i])\n    ydata_death_incr2.append(ydata_death[tm*i+tm]-ydata_death[tm*i])\n    ydata_rec_incr2.append(ydata_rec[tm*i+tm]-ydata_rec[tm*i])\n    \nydata_incr2=np.array(ydata_incr2)\nydata_death_incr2=np.array(ydata_death_incr2)\nydata_rec_incr2=np.array(ydata_rec_incr2)\n'

# %%
'''
# death-case comparison

plt.plot(np.arange(0,len(ydata_incr2)),ydata_incr2*0.142,label='14% New cases (delay of 3 days)')
plt.plot(np.arange(0,len(ydata_incr2))-3/tm,ydata_death_incr2,label='New deaths',alpha=0.7)
plt.xticks(np.arange(-1,70,7/tm),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(-1,len(ydata_incr2))
plt.ylabel('Number')
plt.title('Daily cases')
plt.legend()
plt.savefig('output3/data_death_comp.png',dpi=300)
plt.show()
'''
# Out:
# "\n# death-case comparison\n\nplt.plot(np.arange(0,len(ydata_incr2)),ydata_incr2*0.142,label='14% New cases (delay of 3 days)')\nplt.plot(np.arange(0,len(ydata_incr2))-3/tm,ydata_death_incr2,label='New deaths',alpha=0.7)\nplt.xticks(np.arange(-1,70,7/tm),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)\nplt.xlim(-1,len(ydata_incr2))\nplt.ylabel('Number')\nplt.title('Daily cases')\nplt.legend()\nplt.savefig('output3/data_death_comp.png',dpi=300)\nplt.show()\n"

# %%
'''
# recovered-case comparison

plt.step(np.arange(0,len(ydata_incr2)),ydata_incr2*0.5,label='50% New cases (delay of 25 days)')
plt.step(np.arange(0,len(ydata_incr2))-25/tm,ydata_rec_incr2,label='Recovered',alpha=0.7)
plt.xticks(np.arange(-1,70,7/tm),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(-1,len(ydata_incr2))
plt.ylabel('Number')
plt.title('Daily cases')
plt.legend()
plt.savefig('output3/data_rec_comp.png',dpi=300)
plt.show()
'''
# Out:
# "\n# recovered-case comparison\n\nplt.step(np.arange(0,len(ydata_incr2)),ydata_incr2*0.5,label='50% New cases (delay of 25 days)')\nplt.step(np.arange(0,len(ydata_incr2))-25/tm,ydata_rec_incr2,label='Recovered',alpha=0.7)\nplt.xticks(np.arange(-1,70,7/tm),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)\nplt.xlim(-1,len(ydata_incr2))\nplt.ylabel('Number')\nplt.title('Daily cases')\nplt.legend()\nplt.savefig('output3/data_rec_comp.png',dpi=300)\nplt.show()\n"

# %%
decremento=round((ydata_inf.max()-ydata_inf[-1])/ydata_inf.max()*100)

print('decremento rispetto al massimo ',decremento,'%')
print('casi attuali ',ydata_inf[-1])
print('casi max ',ydata_inf.max())
# Out:
# decremento rispetto al massimo  76.0 %
# casi attuali  26078
# casi max  108257

# %%
# active infected

plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',marker=None,markersize=5,label='Active infected')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata))
plt.ylim(0,115000)
plt.xlabel('Data')
plt.ylabel('Number')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('output3/sirdatacomp_prediction_dataonly.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(11,5))
plt.subplot(1,2,1)
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',markersize=5,label='Infetti attivi')
plt.plot(ydata_terint*10,label='Ricoverati in terapia intensiva (x10)',color='black')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_inf))
plt.ylabel('Totale')
plt.grid()
plt.legend()
plt.subplot(1,2,2)
plt.plot(ydata_terint/ydata_inf*100,color='green')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_inf))
plt.grid()
plt.yticks(np.arange(0,14,2),['0%','2%','4%','6%','8%','10%','12%','14%'])
plt.ylabel('% di ricoverati in terapia intensiva')
plt.tight_layout()
plt.savefig('output3/terapia_intensiva.png',dpi=300)
plt.show()

# %%
plt.plot(ydata_terint/ydata_inf*100,color='green')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=70)
plt.xlim(0,len(ydata_inf))
plt.grid()
plt.yticks(np.arange(0,14,2),['0%','2%','4%','6%','8%','10%','12%','14%'])
plt.ylabel('% di ricoverati in terapia intensiva')
plt.savefig('output3/terint_plot.png',dpi=300)
plt.show()

# %%
ric_ter=np.array(ydata_terint/ydata_inf*100)

(ric_ter[-1]/ric_ter.max())**(-1)
# Out:
# 32.72997848434138

# %%
ydata_terint
# Out:
# array([  26,   35,   36,   56,   64,  105,  140,  166,  229,  295,  351,
#         462,  567,  650,  733,  877, 1028, 1153, 1328, 1518, 1672, 1851,
#        2060, 2257, 2498, 2655, 2857, 3009, 3204, 3396, 3489, 3612, 3732,
#        3856, 3906, 3981, 4023, 4035, 4053, 4068, 3994, 3977, 3898, 3792,
#        3693, 3605, 3497, 3381, 3343, 3260, 3186, 3079, 2936, 2812, 2733,
#        2635, 2573, 2471, 2384, 2267, 2173, 2102, 2009, 1956, 1863, 1795,
#        1694, 1578, 1539, 1501, 1479, 1427, 1333, 1311, 1168, 1034, 1027,
#         999,  952,  893,  855,  808,  775,  762,  749,  716,  676,  640,
#         595,  572,  553,  541,  521,  505,  489,  475,  450,  435,  424,
#         408,  353,  338,  316,  293,  287,  283,  263,  249,  236,  227,
#         220,  209,  207,  177,  163,  168,  161,  152,  148,  127,  115,
#         107,  103,  105,   97,   98,   96,   93,   87,   82,   79,   71,
#          74,   72,   70,   71,   69,   65,   67,   68,   65,   60,   57,
#          53,   50,   50,   49,   47,   49,   48,   49,   46,   41,   44,
#          45,   40,   38,   47,   41,   43,   42,   41,   41,   41,   42,
#          42,   43,   45,   46,   49,   53,   55,   56,   55,   56,   58,
#          58,   66,   68,   69,   64,   69,   65,   66,   69,   67,   74,
#          79,   86,   94])

# %%
# active infected

plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',markersize=5,label='Infetti attivi')
plt.plot(np.arange(len(ydata)),ydata,label='Totale')
plt.plot(np.arange(len(ydata_incr)),np.array(ydata_incr)*10,label='Nuovi casi x 10')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,len(ydata))
plt.ylim(0,230000)
#plt.xlabel('Data')
#plt.ylabel('Number')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('output3/active_data_comp.png',dpi=300)
plt.show()

# %%
plt.plot(np.diff(ydata_death))
plt.show()

# %%
# infetti

interval=6
print(len(ydata)/interval)


ydata_incr7=[]
ydata_tamp7=[]
ydata_death7=[]

for nn in range(int(len(ydata)/interval)):
    ydata_incr7.append([nn,ydata[(nn+1)*interval]-ydata[nn*interval]])
    ydata_tamp7.append([nn,ydata_tamponi[(nn+1)*interval]-ydata_tamponi[nn*interval]])
    ydata_death7.append([nn,ydata_death[(nn+1)*interval]-ydata_death[nn*interval]])
    print(nn*interval,(nn+1)*interval)
    
    
ydata_incr7=np.array(ydata_incr7)
ydata_tamp7=np.array(ydata_tamp7)
ydata_death7=np.array(ydata_death7)

plt.bar(ydata_incr7[:,0]+0.5,ydata_incr7[:,1],label='Nuovi casi')
plt.bar(ydata_tamp7[:,0]+0.5,ydata_tamp7[:,1]/10,alpha=0.2,label='Tamponi / 10')
plt.xticks(np.arange(0,130,7/interval),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_incr7))
plt.title('Nuovi casi')
plt.legend()
plt.grid()
plt.show()
# Out:
# 31.666666666666668
# 0 6
# 6 12
# 12 18
# 18 24
# 24 30
# 30 36
# 36 42
# 42 48
# 48 54
# 54 60
# 60 66
# 66 72
# 72 78
# 78 84
# 84 90
# 90 96
# 96 102
# 102 108
# 108 114
# 114 120
# 120 126
# 126 132
# 132 138
# 138 144
# 144 150
# 150 156
# 156 162
# 162 168
# 168 174
# 174 180
# 180 186

# %%
plt.bar(ydata_death7[:,0]+0.5,ydata_death7[:,1],label='Deceduti',color='black')
plt.legend()
plt.xticks(np.arange(0,130,7/interval),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_incr7))
plt.grid()
plt.show()

# %%
plt.plot(ydata_inf,color='blue',label='Infetti attivi')
plt.plot(ydata_ospedale*10,label='Ospedalizzati (x10)',color='orange')
plt.plot(ydata_terint*100,label='Ricoverati in terapia intensiva (x100)',color='red')
plt.plot(ydata_death*10)
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.grid()
plt.xlim(len(ydata)-90,len(ydata))
plt.ylim(0,30000)
plt.legend()
plt.title('Ricoverati in terapia intensiva')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.bar(ydata_incr7[:,0]+0.5,ydata_incr7[:,1],label='Nuovi casi')
plt.bar(ydata_tamp7[:,0]+0.5,ydata_tamp7[:,1]/10,alpha=0.2,label='Tamponi / 10')
plt.xticks(np.arange(0,130,7/interval),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_incr7))
plt.legend()
plt.grid()
plt.subplot(1,3,2)
plt.bar(ydata_death7[:,0]+0.5,ydata_death7[:,1],label='Deceduti',color='black')
plt.legend()
plt.xticks(np.arange(0,130,7/interval),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata_incr7))
plt.grid()
plt.subplot(1,3,3)
plt.plot(ydata_inf,color='red',label='Infetti attivi')
plt.plot(ydata_terint*10,label='Ricoverati in terapia intensiva (x10)',color='green')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.grid()
plt.legend()
plt.xlim(0,len(ydata))
plt.tight_layout()
plt.savefig('output3/summary_plot.png',dpi=300)
plt.show()

# %%
np.mean(ydata_incr7[-12:,1])
# Out:
# 2298.4166666666665

# %%
np.std(ydata_incr7[-12:,1])
# Out:
# 566.3244554925109

# %%
ydata_incr7[-10:,1]
# Out:
# array([1005, 1603, 1175, 1216, 1140, 1371, 1438, 1643, 2406, 3090])

# %%
plt.plot(ydata/ydata_tamponi*100)
plt.yticks([0,5,10,15,20,25],['0%','5%','10%','15%','20%','25%'])
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(0,len(ydata))
plt.grid()
plt.ylabel('Positivi in rapporto ai tamponi effettuati')
plt.tight_layout()
plt.savefig('output3/pos_tamp.png',dpi=300)
plt.show()

# %%
ymorti=np.diff(ydata_death)

ymorti[172]=ymorti[172]-154   # ricalcolo morti Emilia-Romagna

yter_min=np.min(ydata_terint[-50:])
yosp_min=np.min(ydata_ospedale[-50:])
yinf_min=np.min(ydata_inf[-50:])

print('Infetti minimi ',yinf_min)
print('Infetti minimi ',ydata_inf[-1])

np.max(ydata_terint)
# Out:
# Infetti minimi  12230
# Infetti minimi  26078
# 4068

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(ydata_inf,color='red',label='Infetti attivi')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(len(ydata_inf)-90,len(ydata_inf))
plt.ylim(10000,65000)
plt.legend()
plt.grid()
plt.subplot(2,2,2)
plt.plot(ydata_ospedale,label='Ospedalizzati')
plt.plot(ydata_terint*10,label='Ricoverati in terapia intensiva (x10)')
plt.xticks(np.arange(0,2000,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.grid()
plt.xlim(len(ydata)-90,len(ydata))
plt.ylim(0,12000)
plt.legend()
plt.subplot(2,2,3)
plt.plot(ymorti,label='Deceduti giornalieri',color='black')
plt.legend()
plt.xticks(np.arange(-1,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(len(ydata)-90,len(ydata))
plt.ylim(-1,200)
plt.grid()
plt.subplot(2,2,4)
plt.plot(ydata_terint/ydata_inf*100,color='green',label='Positivi ricoverati in terapia intensiva')
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(len(ydata)-90,len(ydata))
plt.yticks(np.arange(0,2.1,0.5),['0%','0.5%','1%','1.5%','2%'])
plt.ylim(0,2)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig('output3/summary_plot_2.png',dpi=300)
plt.show()

# %%
ymorti_rolling=[]

for i in range(len(ymorti)-6):
    ymortinew=ymorti[i:i+7]
    ymorti_rolling.append(np.mean(ymortinew))
    #print(ymortinew)
    
plt.plot(ymorti_rolling)
plt.xticks(np.arange(-7,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.grid()
plt.xlim(len(ymorti_rolling)-60,len(ymorti_rolling))
plt.ylim(0,50)
plt.show()

# %%
ydata_inf
# Out:
# array([12953, 13263, 13368, 13561, 13791, 14081, 14249, 14406, 14733,
#        14867, 15089, 15360, 16014, 16678, 17503, 18438, 19195, 19714,
#        20753, 21932, 23035, 24156, 25205, 26078])

# %%
plt.plot(ydata_inf)
plt.xticks(np.arange(0,80,7),['8 Ago','15 Ago','22 Ago','29 Ago'])
plt.xlim(0,len(ydata_inf))
plt.grid()
plt.show()

# %%
positivi_giorn=np.diff(ydata)/np.diff(ydata_tamponi)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(positivi_giorn[0:15]*100,label='1° ondata')
plt.plot(positivi_giorn[-15:]*100,label='2° ondata')
plt.xlabel('Numero di giorni dall\'inizio')
plt.title('% tamponi positivi giornalieri ')
plt.yticks([0,10,20,30,40],['0%','10%','20%','30%','40%'])
plt.legend()
plt.grid()
plt.subplot(2,2,2)
plt.plot(ymorti[0:15],label='1° ondata')
plt.plot(ymorti[-15:],label='2° ondata')
plt.xlabel('Numero di giorni dall\'inizio')
plt.title('Numero di decessi giornalieri')
plt.legend()
plt.grid()
plt.subplot(2,2,3)
plt.plot(ydata_ospedale[0:15],label='1° ondata')
plt.plot(ydata_ospedale[-15:],label='2° ondata')
plt.xlabel('Numero di giorni dall\'inizio')
plt.title('Ricoverati in ospedale')
plt.legend()
plt.grid()
plt.subplot(2,2,4)
plt.plot(ydata_terint[0:15],label='1° ondata')
plt.plot(ydata_terint[-15:],label='2° ondata')
plt.xlabel('Numero di giorni dall\'inizio')
plt.title('Ricoverati in terapia intensiva')
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig('output3/seconda_ondata.png',dpi=300)
plt.show()

# %% [markdown]
# # definition of the models

# %%
ydata_inf=np.array(ydata-ydata_rec-ydata_death)
ydata_inf=ydata_inf[177:]

plt.plot(ydata_inf)

# %% [markdown]
# ### definition of SIR 1.0

# %%
# The SIR model differential equations.
def deriv_SIR(y, t, N, beta,gamma):
    S,I,R = y

    dSdt = -(beta*I/N)*S 
    dIdt = (beta*S/N)*I - gamma*I 
    dRdt = gamma*I 
    
    return dSdt, dIdt, dRdt

def SIR(N,beta,gamma,I0=1,R0=0,t=np.arange(0,365)):
    # Definition of the initial conditions
    # I0 and R0 denotes the number of initial infected people (I0) 
    # and the number of people that recovered and are immunized (R0)
    
    # t ise the timegrid
    
    S0=N-I0-R0  # number of people that can still contract the virus
    
    # Initial conditions vector
    y0 = S0, I0, R0

    # Integrate the SIR equations over the time grid, t.
    ret = odeint(deriv_SIR, y0, t, args=(N,beta,gamma))
    S, I, R = np.transpose(ret)
    
    return (t,S,I,R)

# %%
r0_example=4

fin_res_SIR1=SIR(16000,0.1*r0_example,0.1,I0=1,R0=0)
t_vec=fin_res_SIR1[0]
s_vec=fin_res_SIR1[1]
i_vec=fin_res_SIR1[2]
r_vec=fin_res_SIR1[3]

plt.plot(t_vec,s_vec,color='royalblue',label='Susceptible')
plt.plot(t_vec,i_vec,color='red',label='Infected')
plt.plot(t_vec,r_vec,color='green',label='Removed')
#plt.plot(t_vec,r0_example*s_vec/1000*100,color='black',label='R0 x 100',linestyle='--')
plt.xlim(0,200)
#plt.ylim(0,500)
plt.xlabel('Days from the beginning')
plt.ylabel('Total number')
plt.title('R0 = '+str(r0_example))
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig('output/SIR_example.png',dpi=300)
plt.show()

# %%
fin_res_SIR1=SIR(16000,0.4,1/10,I0=1,R0=0)
t_vec=fin_res_SIR1[0]
s_vec=fin_res_SIR1[1]
i_vec=fin_res_SIR1[2]
r_vec=fin_res_SIR1[3]

fin_res_SIR2=SIR(16000,0.4,1/30,I0=1,R0=0)
t_vec2=fin_res_SIR2[0]
s_vec2=fin_res_SIR2[1]
i_vec2=fin_res_SIR2[2]
r_vec2=fin_res_SIR2[3]

plt.fill_between(t_vec,s_vec,s_vec2,color='royalblue',label='Susceptible')
plt.fill_between(t_vec,i_vec,i_vec2,color='red',label='Infected')
plt.fill_between(t_vec,r_vec,r_vec2,color='green',label='Removed')
#plt.plot(t_vec,r0_example*s_vec/1000*100,color='black',label='R0 x 100',linestyle='--')
plt.xticks(np.arange(0,250,30),['1 Nov','1 Dec','1 Jan','1 Feb','1 Mar','1 Apr','1 May','1 Jun'])
plt.xlim(0,151)
#plt.ylim(0,500)
plt.xlabel('Days from the beginning')
plt.ylabel('Total number')
plt.title('Simulation of Codogno (free expansion)')
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig('output/SIR_example_codogno.png',dpi=300)
plt.show()

# %%
r0_example=1.6

fin_res_SIR1=SIR(6*10**7,1/14*r0_example,1/14,I0=ydata_inf[0],R0=0)
t_vec=fin_res_SIR1[0]
i_vec=fin_res_SIR1[2]

plt.figure(figsize=(9,5))
plt.subplot(1,2,1)
plt.plot(ydata_inf,'.',color='red',label='Infetti attivi (dati)')
plt.plot(t_vec,i_vec,label='Modello con R0='+str(r0_example))
plt.plot(t_vec,i_vec*0.5/100,linestyle='--',label='Terapia intensiva (0.5% degli infetti)')
plt.xticks(np.arange(-11,180,7),['8 Ago','15 Ago','22 Ago','29 Ago','5 Set','12 Set','19 Set','26 Set','3 Ott','10 Ott','17 Ott','24 Ott','31 Ott','7 Nov','14 Nov','21 Nov','28 Nov','5 Dic','12 Dic','19 Dic','26 Dic'],rotation=60)
plt.ylim(10**4,4*10**4)
plt.xlim(0,25)
#plt.yscale('log')
plt.legend()
plt.grid()
plt.subplot(1,2,2)
plt.plot(ydata_inf,'.',color='red',label='Infetti attivi (dati)')
#plt.plot(ydata_terint[177:])
plt.plot(t_vec,i_vec,label='Modello con R0='+str(r0_example))
plt.plot(t_vec,i_vec*0.5/100,linestyle='--',label='Terapia intensiva (0.5% degli infetti)')
plt.plot([0,300],[4000,4000],color='black',linestyle='-.',label='Ricoverati Marzo/Aprile 2019 ')
plt.xticks(np.arange(-11,300,14),['8 Ago','22 Ago','5 Set','19 Set','3 Ott','17 Ott','31 Ott','14 Nov','28 Nov','12 Dic','26 Dic','9 Gen','23 Gen','6 Feb','20 Feb','6 Mar','20 Mar'],rotation=60)
plt.ylim(50,10**6)
plt.xlim(0,150)
plt.yscale('log')
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig('output3/proiezioni_2019.png',dpi=300)
plt.show()

# %%
np.mean(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf)*100)
# Out:
# 98.7810531045835

# %%
plt.plot(ydata_terint)
plt.xticks(np.arange(0,200,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug','13 Lug','20 Lug','27 Lug','3 Ago','10 Ago','17 Ago','24 Ago'],rotation=90)
plt.xlim(120,len(ydata_terint))
plt.ylim(20,120)
plt.grid()
plt.show()

# %% [markdown]
# ### definition of SIR 2.0

# %%
# The SIR model differential equations.
def deriv_SIR_2(y, t, N, beta1,gamma,tau=10**6,t_thresh=14):
    S,I,R = y
    
    if t<=t_thresh:      # il lockdown nazionale inizia al 14° giorno 
        B=beta1
    else: 
        B=beta1*np.exp(-(t-t_thresh)/tau)

    dSdt = -(B*I/N)*S 
    dIdt = (B*S/N)*I - gamma*I 
    dRdt = gamma*I 
    
    return dSdt, dIdt, dRdt


def SIR_2(N,beta1,gamma,tau=10**6,t_thresh=14,I0=1,R0=0,t=np.arange(0,365)):
    # Definition of the initial conditions
    # I0 and R0 denotes the number of initial infected people (I0) 
    # and the number of people that recovered and are immunized (R0)
    
    # t ise the timegrid
    
    S0=N-I0-R0  # number of people that can still contract the virus
    
    # Initial conditions vector
    y0 = S0, I0, R0

    # Integrate the SIR equations over the time grid, t.
    ret = odeint(deriv_SIR_2, y0, t, args=(N,beta1,gamma,tau,t_thresh))
    S, I, R = np.transpose(ret)
    
    return (t,S,I,R)

# %% [markdown]
# # fitting the active infected

# %%
# 3 parameter fit for the active infected

def optimizer_adv(R0,tau,t_thresh):
    
    asympt=3
    
    fin_result_updated=SIR_2(6*10**7,R0*1/21,1/21,tau,t_thresh,I0=asympt*ydata_inf[0])
    i_vec=fin_result_updated[2]/asympt
    
    pesi=np.exp(-np.arange(len(ydata_inf))/7)    # 
    pesi=pesi[::-1]
    
    accuracy=np.sum((ydata_inf-i_vec[0:len(ydata_inf)])**2)   #mean squared error. This is used for the optimization
    
    errperc=np.mean(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100
    stdperc=np.std(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100
    
    return accuracy,errperc,stdperc

# %%
# grid on 3 parameters
R0grid=np.linspace(7.5,8.5,50)
taugrid=np.linspace(25,27,200)
#ttreshgrid=np.linspace(0,10,15)

res_scan=[]
counter=0
counter2=0
cycle_tot=len(R0grid)*len(taugrid) #*len(ttreshgrid)

time1=pctime.time()

# minimization

for r in R0grid:
    for tau in taugrid:
        opt_res=optimizer_adv(r,tau,0)
        res_scan.append([r,tau,0,opt_res[0],opt_res[1],opt_res[2]])
        counter=counter+1
        counter2=counter2+1
        if counter2==cycle_tot/10:
            time2=pctime.time()
            remtime=round((time2-time1)/counter*(cycle_tot-counter),1)
            print('completed ',round(counter/cycle_tot*100,1),'%. Remaining time ',remtime,'sec')
            counter2=0
        
res_scan=np.array(res_scan)
# Out:
# completed  10.0 %. Remaining time  34.8 sec
# completed  20.0 %. Remaining time  28.2 sec
# completed  30.0 %. Remaining time  24.2 sec
# completed  40.0 %. Remaining time  20.5 sec
# completed  50.0 %. Remaining time  17.2 sec
# completed  60.0 %. Remaining time  14.3 sec
# completed  70.0 %. Remaining time  10.9 sec
# completed  80.0 %. Remaining time  7.6 sec
# completed  90.0 %. Remaining time  3.8 sec
# completed  100.0 %. Remaining time  0.0 sec

# %%
df_res_scan=pd.DataFrame(res_scan)
df_res_scan.columns=['R0','tau','t_thresh','MSE','mean err%','std err%']

df_res_scan.sort_values(by='MSE')
# Out:
#             R0        tau  t_thresh           MSE  mean err%   std err%
# 4782  7.969388  26.829146       0.0  1.518481e+09   7.168738   6.550606
# 4973  7.989796  26.738693       0.0  1.519961e+09   7.211169   6.597064
# 4781  7.969388  26.819095       0.0  1.521418e+09   7.257180   6.626497
# 4783  7.969388  26.839196       0.0  1.522039e+09   7.087561   6.472762
# 4972  7.989796  26.728643       0.0  1.522419e+09   7.315562   6.660098
# ...        ...        ...       ...           ...        ...        ...
# 9995  8.500000  26.959799       0.0  3.940510e+11  66.437662  28.813990
# 9996  8.500000  26.969849       0.0  3.984630e+11  66.855063  29.011984
# 9997  8.500000  26.979899       0.0  4.029105e+11  67.273578  29.210993
# 9998  8.500000  26.989950       0.0  4.073939e+11  67.693207  29.411017
# 9999  8.500000  27.000000       0.0  4.119132e+11  68.113948  29.612052
#
# [10000 rows x 6 columns]

# %%
par_ideal=np.array(df_res_scan.sort_values(by='MSE').iloc[0,0:])

par_ideal[0:3]
# Out:
# array([ 7.96938776, 26.82914573,  0.        ])

# %%
8.07*1/21
# Out:
# 0.3842857142857143

# %%
fin_result_updated=SIR_2(6*10**7,par_ideal[0]*1/21,1/21,par_ideal[1],t_thresh=par_ideal[2],I0=3*ydata_inf[0])

t=fin_result_updated[0]
s_vec=fin_result_updated[1]
i_vec=fin_result_updated[2]
r_vec=fin_result_updated[3]

plt.figure(figsize=(7,5))
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',label='Active infected (data)',marker='.')
plt.plot(t, i_vec/3, label='Active infected (model, best-fit)',color='blue',linestyle='--')
#plt.fill_between(t, i_vec*(1+par_ideal[5]/100*2.65)/3,i_vec*(1-par_ideal[5]/100*2.65)/3, label='Active infected (model, 99% of data)',color='blue',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,250000],color='orange')
plt.plot(np.zeros(2)+14,[-1000,250000],color='purple')
plt.xticks(np.arange(0,150,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu','8 Giu','15 Giu','22 Giu','29 Giu','6 Lug'],rotation=30)
plt.xlim(0,150)
plt.ylim(100,2*10**5)
#plt.yscale('log')
plt.annotate("Lockdown", xy=(14,10000), xytext=(3,40000), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.annotate("Phase 2", xy=(70,ydata_inf.max()), xytext=(80,ydata_inf.max()/10), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.xlabel('Data')
plt.ylabel('Counter')
plt.yscale('log')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('output3/fit_con_incertezza.png',dpi=300)
plt.show()

# %%
i_vec[70]*(1+par_ideal[5]/100*2),i_vec[70]*(1-par_ideal[5]/100*2)
# Out:
# (325136.1872831458, 249811.11911421973)

# %%
#plt.plot(t,s_vec/(60*10**6),label='Suscettibili')
plt.plot(t,i_vec,label='Infetti',color='purple')
plt.plot(t,i_vec/3,label='Sintomatici',color='red')
plt.plot(t,r_vec,label='Rimossi',color='black')
plt.yscale('log')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,100)
plt.ylim(200,10**6)
plt.grid()
#plt.ylabel('S/N')
plt.legend()
plt.savefig('output/suscettibili.png',dpi=300)
plt.show()

# %%
#export

t_date=pd.to_datetime(t,unit='D',origin=pd.Timestamp('2020-02-24'))

export_v2 = pd.DataFrame({'date':t_date,'t':t,'s':s_vec,'i':i_vec,'r':r_vec})
export_v2.to_csv('output3/nazionale_v2.csv',index=False)

# %%
export_v2
# Out:
#           date    t             s            i             r
# 0   2020-02-24    0  5.999934e+07   663.000000  0.000000e+00
# 1   2020-02-25    1  5.999905e+07   917.507036  3.734669e+01
# 2   2020-02-26    2  5.999866e+07  1252.522434  8.865801e+01
# 3   2020-02-27    3  5.999815e+07  1687.556073  1.582205e+02
# 4   2020-02-28    4  5.999750e+07  2245.101040  2.513207e+02
# ..         ...  ...           ...          ...           ...
# 360 2021-02-18  360  5.898333e+07     0.604425  1.016669e+06
# 361 2021-02-19  361  5.898333e+07     0.576318  1.016669e+06
# 362 2021-02-20  362  5.898333e+07     0.549518  1.016669e+06
# 363 2021-02-21  363  5.898333e+07     0.523964  1.016669e+06
# 364 2021-02-22  364  5.898333e+07     0.499598  1.016669e+06
#
# [365 rows x 5 columns]

# %% [markdown]
# # computation of national R0

# %% [markdown]
# ### using data of last 5 days

# %%
today=len(xdata)

def minimizer(R0,t1=today-5,t2=today):
    
    #true data
    ydata_inf_2=np.array(ydata_inf[t1:t2])
    xdata_2=np.arange(0,len(ydata_inf_2))
    
    #print(ydata_inf_2)
    
    #model
    fin_result=SIR(60*10**6,1/14*R0,1/14,I0=ydata_inf_2[0])
    i_vec=fin_result[2]
    i_vec_2=i_vec[0:len(xdata_2)]
    
    #average error
    error=np.sum((ydata_inf_2-i_vec_2)**2/ydata_inf_2)/(len(ydata_inf)-1)
    
    return error

minimizer_vec=np.vectorize(minimizer)


#definition of the ideal r0

xgrid=np.arange(0.01,1.3,0.01)
ygrid=minimizer_vec(xgrid)
r0_ideal=round(xgrid[np.argmin(ygrid)],2)
print('r0 ',r0_ideal)

plt.plot(xgrid,ygrid)
plt.show()
# Out:
# r0  0.78

# %%
ydata_inf_2=np.array(ydata_inf[today-5:today])
xdata_2=np.arange(0,len(ydata_inf_2))

fin_result=SIR(60*10**6,1/14*r0_ideal,1/14,I0=ydata_inf_2[0])

t_R0=fin_result[0]
#s_vec=fin_result[1]
i_vec_R0=fin_result[2]
#r_vec=fin_result[3]

plt.figure(figsize=(5,5))
plt.errorbar(xdata_2,ydata_inf_2,np.sqrt(ydata_inf_2),color='red',linestyle='None',marker='s',label='Infected (data)')
plt.plot(t_R0, i_vec_R0, 'r--', label='Infected (model)')
#plt.yscale('log')
#plt.xticks(np.arange(14,70,7),['21 Feb','28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr','10 Apr'],rotation=30)
plt.xlim(-0.5,4.5)
plt.ylim(60000,85000)
#plt.ylim(0,300)
plt.xlabel('Day')
plt.ylabel('Counter')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.title('R0='+str(r0_ideal)+' (last 5 days)')
plt.tight_layout()
plt.savefig('output3/r0-5days.png',dpi=300)
plt.show()

# %% [markdown]
# ### scan of R0 over time

# %%
time_window=5

def minimizer_gen(t1,t2,xgrid=np.arange(0.1,5,0.01)):

    ygrid=minimizer_vec(xgrid,t1=t1,t2=t2)
    r0_ideal=round(xgrid[np.argmin(ygrid)],2)

    return r0_ideal

r0_time=[]
scangrid=np.linspace(0,10,100)

for i in range(0,today-(time_window-1)):
    min_val=minimizer_gen(i,i+time_window,xgrid=scangrid)
    r0_time.append(min_val)
    scangrid=np.linspace(min_val/2,min_val*2,100)  #the grid change over the time (this speed up the process)
    print('Day n',i,' R0=',min_val)
    print(i,i+time_window,len(ydata_inf))
    
r0_time=np.array(r0_time)
# Out:
# Day n 0  R0= 5.56
# 0 5 132
# Day n 1  R0= 5.31
# 1 6 132
# Day n 2  R0= 5.87
# 2 7 132
# Day n 3  R0= 5.16
# 3 8 132
# Day n 4  R0= 4.69
# 4 9 132
# Day n 5  R0= 4.48
# 5 10 132
# Day n 6  R0= 3.53
# 6 11 132
# Day n 7  R0= 3.69
# 7 12 132
# Day n 8  R0= 3.75
# 8 13 132
# Day n 9  R0= 3.92
# 9 14 132
# Day n 10  R0= 4.1
# 10 15 132
# Day n 11  R0= 3.98
# 11 16 132
# Day n 12  R0= 3.62
# 12 17 132
# Day n 13  R0= 3.4
# 13 18 132
# Day n 14  R0= 3.14
# 14 19 132
# Day n 15  R0= 3.62
# 15 20 132
# Day n 16  R0= 3.35
# 16 21 132
# Day n 17  R0= 3.1
# 17 22 132
# Day n 18  R0= 3.01
# 18 23 132
# Day n 19  R0= 2.74
# 19 24 132
# Day n 20  R0= 2.62
# 20 25 132
# Day n 21  R0= 2.7
# 21 26 132
# Day n 22  R0= 2.7
# 22 27 132
# Day n 23  R0= 2.78
# 23 28 132
# Day n 24  R0= 2.53
# 24 29 132
# Day n 25  R0= 2.3
# 25 30 132
# Day n 26  R0= 2.09
# 26 31 132
# Day n 27  R0= 1.99
# 27 32 132
# Day n 28  R0= 1.96
# 28 33 132
# Day n 29  R0= 1.93
# 29 34 132
# Day n 30  R0= 1.9
# 30 35 132
# Day n 31  R0= 1.76
# 31 36 132
# Day n 32  R0= 1.6
# 32 37 132
# Day n 33  R0= 1.5
# 33 38 132
# Day n 34  R0= 1.41
# 34 39 132
# Day n 35  R0= 1.43
# 35 40 132
# Day n 36  R0= 1.45
# 36 41 132
# Day n 37  R0= 1.43
# 37 42 132
# Day n 38  R0= 1.41
# 38 43 132
# Day n 39  R0= 1.39
# 39 44 132
# Day n 40  R0= 1.31
# 40 45 132
# Day n 41  R0= 1.21
# 41 46 132
# Day n 42  R0= 1.17
# 42 47 132
# Day n 43  R0= 1.22
# 43 48 132
# Day n 44  R0= 1.24
# 44 49 132
# Day n 45  R0= 1.24
# 45 50 132
# Day n 46  R0= 1.24
# 46 51 132
# Day n 47  R0= 1.18
# 47 52 132
# Day n 48  R0= 1.14
# 48 53 132
# Day n 49  R0= 1.12
# 49 54 132
# Day n 50  R0= 1.12
# 50 55 132
# Day n 51  R0= 1.1
# 51 56 132
# Day n 52  R0= 1.07
# 52 57 132
# Day n 53  R0= 1.05
# 53 58 132
# Day n 54  R0= 1.0
# 54 59 132
# Day n 55  R0= 0.97
# 55 60 132
# Day n 56  R0= 0.94
# 56 61 132
# Day n 57  R0= 0.94
# 57 62 132
# Day n 58  R0= 0.94
# 58 63 132
# Day n 59  R0= 0.97
# 59 64 132
# Day n 60  R0= 0.96
# 60 65 132
# Day n 61  R0= 0.97
# 61 66 132
# Day n 62  R0= 0.9
# 62 67 132
# Day n 63  R0= 0.85
# 63 68 132
# Day n 64  R0= 0.82
# 64 69 132
# Day n 65  R0= 0.82
# 65 70 132
# Day n 66  R0= 0.94
# 66 71 132
# Day n 67  R0= 0.94
# 67 72 132
# Day n 68  R0= 0.78
# 68 73 132
# Day n 69  R0= 0.65
# 69 74 132
# Day n 70  R0= 0.52
# 70 75 132
# Day n 71  R0= 0.44
# 71 76 132
# Day n 72  R0= 0.67
# 72 77 132
# Day n 73  R0= 0.68
# 73 78 132
# Day n 74  R0= 0.69
# 74 79 132
# Day n 75  R0= 0.76
# 75 80 132
# Day n 76  R0= 0.73
# 76 81 132
# Day n 77  R0= 0.59
# 77 82 132
# Day n 78  R0= 0.48
# 78 83 132
# Day n 79  R0= 0.49
# 79 84 132
# Day n 80  R0= 0.48
# 80 85 132
# Day n 81  R0= 0.64
# 81 86 132
# Day n 82  R0= 0.62
# 82 87 132
# Day n 83  R0= 0.61
# 83 88 132
# Day n 84  R0= 0.6
# 84 89 132
# Day n 85  R0= 0.56
# 85 90 132
# Day n 86  R0= 0.63
# 86 91 132
# Day n 87  R0= 0.65
# 87 92 132
# Day n 88  R0= 0.63
# 88 93 132
# Day n 89  R0= 0.59
# 89 94 132
# Day n 90  R0= 0.47
# 90 95 132
# Day n 91  R0= 0.37
# 91 96 132
# Day n 92  R0= 0.34
# 92 97 132
# Day n 93  R0= 0.3
# 93 98 132
# Day n 94  R0= 0.43
# 94 99 132
# Day n 95  R0= 0.46
# 95 100 132
# Day n 96  R0= 0.61
# 96 101 132
# Day n 97  R0= 0.67
# 97 102 132
# Day n 98  R0= 0.62
# 98 103 132
# Day n 99  R0= 0.66
# 99 104 132
# Day n 100  R0= 0.6
# 100 105 132
# Day n 101  R0= 0.61
# 101 106 132
# Day n 102  R0= 0.64
# 102 107 132
# Day n 103  R0= 0.61
# 103 108 132
# Day n 104  R0= 0.52
# 104 109 132
# Day n 105  R0= 0.38
# 105 110 132
# Day n 106  R0= 0.41
# 106 111 132
# Day n 107  R0= 0.35
# 107 112 132
# Day n 108  R0= 0.34
# 108 113 132
# Day n 109  R0= 0.42
# 109 114 132
# Day n 110  R0= 0.51
# 110 115 132
# Day n 111  R0= 0.56
# 111 116 132
# Day n 112  R0= 0.4
# 112 117 132
# Day n 113  R0= 0.47
# 113 118 132
# Day n 114  R0= 0.47
# 114 119 132
# Day n 115  R0= 0.54
# 115 120 132
# Day n 116  R0= 0.73
# 116 121 132
# Day n 117  R0= 0.62
# 117 122 132
# Day n 118  R0= 0.51
# 118 123 132
# Day n 119  R0= 0.42
# 119 124 132
# Day n 120  R0= 0.49
# 120 125 132
# Day n 121  R0= 0.59
# 121 126 132
# Day n 122  R0= 0.58
# 122 127 132
# Day n 123  R0= 0.6
# 123 128 132
# Day n 124  R0= 0.68
# 124 129 132
# Day n 125  R0= 0.62
# 125 130 132
# Day n 126  R0= 0.57
# 126 131 132
# Day n 127  R0= 0.78
# 127 132 132

# %%
plt.figure(figsize=(5,5))
plt.plot(r0_time)
plt.xticks(np.arange(0-(time_window-5),80,7),['28 Feb','6 Mar','13 Mar','20 Mar','27 Mar','3 Apr','10 Apr','17 Apr','24 Apr','1 May','8 May','15 May'],rotation=60)
plt.xlim(0,today-4)
#plt.xlim(19,today-9)
plt.ylabel('$R_0$')
plt.ylim(0,7)
plt.grid()
plt.title('Evolution of $R_0$')
plt.savefig('output3/r0-evo.png',dpi=300)
plt.show()

# %%
# export R0 over time

df_r0=pd.DataFrame(pd.to_datetime(np.arange(len(r0_time)),unit='D',origin='2020-02-28'))
df_r0['R0']=r0_time
df_r0.columns=['Data','R0']

df_r0.to_csv('output3/r0.csv',index=False)

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.plot(np.arange(len(ydata)),ydata,label='Totale casi')
plt.plot(np.arange(len(ydata)),ydata_death,label='Deceduti totali')
plt.plot(np.arange(len(ydata)),ydata_rec,label='Guariti totali')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,len(ydata))
plt.ylabel('Numero')
plt.title('Curve cumulative')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.subplot(2,2,2)
plt.plot(np.arange(len(ydata_incr)),ydata_incr,label='Nuovi casi')
plt.plot(np.arange(len(ydata_incr)),ydata_death_incr,label='Deceduti giornalieri')
plt.plot(np.arange(len(ydata_incr)),ydata_rec_incr,label='Guariti giornalieri')
plt.xticks(np.arange(-1,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(-1,len(ydata_incr))
plt.ylabel('Numero')
plt.title('Curve incrementali')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.subplot(2,2,3)
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',linestyle='None',marker='.',label='Infetti attivi (dati)')
plt.plot(t, i_vec/3, label='Infetti attivi (modello, best-fit)',color='red',linestyle='--')
plt.fill_between(t, i_vec*(1+par_ideal[4]/100*2)/3,i_vec*(1-par_ideal[4]/100*2)/3, label='Infetti attivi (modello, 95% C.L.)',color='red',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,140000],color='brown')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,100)
plt.ylim(0,140000)
plt.annotate("Lockdown", xy=(14,10000), xytext=(3,40000), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.title('Curva cumulativa degli infetti attivi')
plt.ylabel('Numero')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.subplot(2,2,4)
plt.plot(r0_time,color='purple')
plt.xticks(np.arange(0-time_window+1,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,today-4)
#plt.xlim(19,today-9)
plt.ylabel('$R_0$')
plt.ylim(0,5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.title('Evoluzione di $R_0$')
plt.tight_layout()
plt.savefig('output3/4plots.png',dpi=300)

# %%
len(ydata_inf)
# Out:
# 132

# %% [markdown]
# ### future forecasting

# %%
# The SIR model differential equations.
def deriv_SIR_2_future(y, t, N, beta1,gamma,newR0,tau=10**6,t_thresh=14):
    S,I,R = y
    
    if t<=t_thresh:      # il lockdown nazionale inizia al 14° giorno 
        B=beta1
    elif t>t_thresh and t<=70: 
        B=beta1*np.exp(-(t-t_thresh)/tau)
    elif t>70:
        B=newR0*gamma
        #B=beta1*np.exp(-(70-t_thresh)/tau)+0.05*gamma*(t-70)
        #print(B,t)

    dSdt = -(B*I/N)*S 
    dIdt = (B*S/N)*I - gamma*I 
    dRdt = gamma*I 
    
    return dSdt, dIdt, dRdt


def SIR_2_future(N,beta1,gamma,newR0,tau=10**6,t_thresh=14,I0=1,R0=0,t=np.arange(0,365)):
    # Definition of the initial conditions
    # I0 and R0 denotes the number of initial infected people (I0) 
    # and the number of people that recovered and are immunized (R0)
    
    # t ise the timegrid
    
    S0=N-I0-R0  # number of people that can still contract the virus
    
    # Initial conditions vector
    y0 = S0, I0, R0

    # Integrate the SIR equations over the time grid, t.
    ret = odeint(deriv_SIR_2_future, y0, t, args=(N,beta1,gamma,newR0,tau,t_thresh))
    S, I, R = np.transpose(ret)
    
    return (t,S,I,R)

# %%
asympt=3

i_vec_future050=SIR_2_future(6*10**7,par_ideal[0]*1/21,1/21,0.5,par_ideal[1],t_thresh=par_ideal[2],I0=asympt*ydata_inf[0])[2]
i_vec_future100=SIR_2_future(6*10**7,par_ideal[0]*1/21,1/21,1.0,par_ideal[1],t_thresh=par_ideal[2],I0=asympt*ydata_inf[0])[2]
i_vec_future110=SIR_2_future(6*10**7,par_ideal[0]*1/21,1/21,1.1,par_ideal[1],t_thresh=par_ideal[2],I0=asympt*ydata_inf[0])[2]
i_vec_future120=SIR_2_future(6*10**7,par_ideal[0]*1/21,1/21,1.20,par_ideal[1],t_thresh=par_ideal[2],I0=asympt*ydata_inf[0])[2]

plt.figure(figsize=(7,5))
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',linestyle='None',marker='.',label='Active infected (data)')
plt.fill_between(t, i_vec_future100/asympt,i_vec_future050/asympt,color='green',label='Model, $\\tilde{R_0}$ between 0.5 e 1',alpha=0.5)
plt.fill_between(t, i_vec_future110/asympt,i_vec_future100/asympt,color='orange',label='Model, $\\tilde{R_0}$ between 1 e 1.1',alpha=0.5)
plt.fill_between(t, i_vec_future120/asympt,i_vec_future110/asympt,color='red',label='Model, $\\tilde{R_0}$ between 1.1 e 1.2',alpha=0.5)
#plt.plot(t, i_vec_future05/asympt, label='Modello, R$_0^{riapertura}$=0.5')
#plt.plot(t, i_vec_future10/asympt, label='Modello, R$_0^{riapertura}$=1')
#plt.plot(t, i_vec_future15/asympt, label='Modello, R$_0^{riapertura}$=1.1')
#plt.plot(t, i_vec_future20/asympt, label='Modello, R$_0^{riapertura}$=1.2')
#plt.fill_between(t, i_vec_future*(1+par_ideal[4]/100*2)/asympt,i_vec_future*(1-par_ideal[4]/100*2)/asympt, label='Infetti attivi (modello, 95% C.L.)',color='red',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,10**7],color='purple')
plt.xticks(np.arange(6,360,30),['1 Mar','1 Apr','1 May','1 Jun','1 Jul','1 Ago','1 Sep','1 Oct','1 Nov','1 Dec','1 Jan','1 Feb'],rotation=30)
plt.xlim(0,360)
plt.ylim(100,ydata_inf.max()*4.3)
#plt.ylim(100,10**7)
#plt.yscale('log')
plt.annotate("Lockdown", xy=(14,ydata_inf.max()*0.1), xytext=(3,ydata_inf.max()*2), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.annotate("Phase 2", xy=(70,ydata_inf.max()), xytext=(80,ydata_inf.max()*2), arrowprops=dict(arrowstyle="->"),fontsize=13)
#plt.xlabel('Data')
plt.ylabel('Total number')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
#plt.title('2 asymptomatics for each symptomatics')
plt.tight_layout()
plt.savefig('output3/predizioni_future.png',dpi=300)
plt.show()

# %%
#export

t_date=pd.to_datetime(t,unit='D',origin=pd.Timestamp('2020-02-24'))

export_forecast = pd.DataFrame({'date':t_date,'t':t,'R0=0.5':i_vec_future050,'R0=1':i_vec_future100,'R0=1.1':i_vec_future110,'R0=1.2':i_vec_future120})
export_forecast.to_csv('output3/predizioni_future_export.csv',index=False)

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',label='Active infected (data)',marker='.')
plt.plot(t, i_vec/3, label='Active infected (model, best-fit)',color='blue',linestyle='--')
#plt.fill_between(t, i_vec*(1+par_ideal[5]/100*2.65)/3,i_vec*(1-par_ideal[5]/100*2.65)/3, label='Active infected (model, 99% of data)',color='blue',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,250000],color='purple')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 May','18 May','25 May','1 Jun'],rotation=30)
plt.xlim(0,100)
plt.ylim(100,2*10**5)
#plt.yscale('log')
plt.annotate("Lockdown", xy=(14,10000), xytext=(3,40000), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.annotate("Phase 2", xy=(70,ydata_inf.max()), xytext=(80,ydata_inf.max()/10), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.xlabel('Data')
plt.ylabel('Total number')
plt.yscale('log')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.subplot(1,2,2)
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',linestyle='None',marker='.',label='Active infected (data)')
plt.fill_between(t, i_vec_future100/asympt,i_vec_future050/asympt,color='green',label='Model, $\\tilde{R_0}$ between 0.5 e 1',alpha=0.5)
plt.fill_between(t, i_vec_future110/asympt,i_vec_future100/asympt,color='orange',label='Model, $\\tilde{R_0}$ between 1 e 1.1',alpha=0.5)
plt.fill_between(t, i_vec_future120/asympt,i_vec_future110/asympt,color='red',label='Model, $\\tilde{R_0}$ between 1.1 e 1.2',alpha=0.5)
#plt.plot(t, i_vec_future05/asympt, label='Modello, R$_0^{riapertura}$=0.5')
#plt.plot(t, i_vec_future10/asympt, label='Modello, R$_0^{riapertura}$=1')
#plt.plot(t, i_vec_future15/asympt, label='Modello, R$_0^{riapertura}$=1.1')
#plt.plot(t, i_vec_future20/asympt, label='Modello, R$_0^{riapertura}$=1.2')
#plt.fill_between(t, i_vec_future*(1+par_ideal[4]/100*2)/asympt,i_vec_future*(1-par_ideal[4]/100*2)/asympt, label='Infetti attivi (modello, 95% C.L.)',color='red',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,10**7],color='purple')
plt.xticks(np.arange(6,360,30),['1 Mar','1 Apr','1 May','1 Jun','1 Jul','1 Ago','1 Sep','1 Oct','1 Nov','1 Dec','1 Jan','1 Feb'],rotation=30)
plt.xlim(0,360)
plt.ylim(100,ydata_inf.max()*4.3)
#plt.ylim(100,10**7)
#plt.yscale('log')
plt.annotate("Lockdown", xy=(14,ydata_inf.max()*0.1), xytext=(3,ydata_inf.max()*2), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.annotate("Phase 2", xy=(70,ydata_inf.max()), xytext=(80,ydata_inf.max()*2), arrowprops=dict(arrowstyle="->"),fontsize=13)
#plt.xlabel('Data')
plt.ylabel('Total number')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
#plt.title('2 asymptomatics for each symptomatics')
plt.tight_layout()
plt.savefig('output3/model_predictions.png',dpi=300)
plt.show()

# %% [markdown]
# ### SIR doubling time

# %%
def doubling_R0(R0):
    sim_res=SIR(10**6,1/14*R0,1/14,I0=100,R0=0,t=np.arange(0,365))
    mask=(sim_res[2]>=200) & (sim_res[2]<=1000)
    sim_time=sim_res[0]
    
    return sim_time[mask][0]

doubling_R0_vec=np.vectorize(doubling_R0)

# %%
R0grid=np.arange(1.1,6,0.1)

doubling_R0_vec(R0grid)
# Out:
# array([98, 49, 33, 25, 20, 17, 14, 13, 11, 10,  9,  9,  8,  7,  7,  7,  6,
#         6,  6,  5,  5,  5,  5,  5,  4,  4,  4,  4,  4,  4,  4,  4,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  2])

# %%
plt.plot(doubling_R0_vec(R0grid),R0grid)
plt.ylim(1,6)
plt.xlim(2,10)
plt.xlabel('Tempo di raddoppio')
plt.ylabel('$R_0$')
plt.show()

# %% [markdown]
# ## Test nuova procedura di fit

# %%
'''
# 3 parameter fit for the active infected

def optimizer_adv(R0,gamma,tau,t_thresh):
    
    asympt=3
    
    fin_result_updated=SIR_2(6*10**7,R0*gamma,gamma,tau,t_thresh,I0=asympt*ydata_inf[0])
    i_vec=fin_result_updated[2]/asympt
    
    pesi=np.exp(-np.arange(len(ydata_inf))/7)    # 
    pesi=pesi[::-1]
    
    accuracy=np.sum((ydata_inf-i_vec[0:len(ydata_inf)])**2)   #mean squared error. This is used for the optimization
    
    errperc=np.mean(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100
    stdperc=np.std(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100
    
    return accuracy,errperc,stdperc


# grid on 3 parameters
R0grid=np.linspace(3,9,10)
gammagrid=np.linspace(0,0.2,10)
taugrid=np.linspace(23,35,10)
ttreshgrid=np.linspace(0,15,5)

res_scan=[]
counter=0
counter2=0
cycle_tot=len(R0grid)*len(gammagrid)*len(taugrid)*len(ttreshgrid)

time1=pctime.time()

# minimization

for r in R0grid:
    for g in gammagrid:
        for tau in taugrid:
            for tt in ttreshgrid:
                opt_res=optimizer_adv(r,g,tau,tt)
                res_scan.append([r,g,tau,tt,opt_res[0],opt_res[1],opt_res[2]])
                counter=counter+1
                counter2=counter2+1
                if counter2==cycle_tot/10:
                    time2=pctime.time()
                    remtime=round((time2-time1)/counter*(cycle_tot-counter),1)
                    print('completed ',round(counter/cycle_tot*100,1),'%. Remaining time ',remtime,'sec')
                    counter2=0
        
res_scan=np.array(res_scan)

df_res_scan=pd.DataFrame(res_scan)
df_res_scan.columns=['R0','gamma','tau','t_thresh','MSE','mean err%','std err%']

print(df_res_scan.sort_values(by='MSE'))

par_ideal=np.array(df_res_scan.sort_values(by='MSE').iloc[0,0:])

fin_result_updated=SIR_2(6*10**7,par_ideal[0]*par_ideal[1],par_ideal[1],par_ideal[2],t_thresh=par_ideal[3],I0=3*ydata_inf[0])

t=fin_result_updated[0]
s_vec=fin_result_updated[1]
i_vec=fin_result_updated[2]
r_vec=fin_result_updated[3]

plt.figure(figsize=(7,5))
plt.plot(np.arange(len(ydata_inf)),ydata_inf,color='red',linestyle='None',marker='.',label='Infetti attivi (dati)')
plt.plot(t, i_vec/3, label='Infetti attivi (modello, best-fit)',color='red',linestyle='--')
plt.fill_between(t, i_vec*(1+par_ideal[5]/100*2)/3,i_vec*(1-par_ideal[5]/100*2)/3, label='Infetti attivi (modello, 95% C.L.)',color='red',alpha=.2)
plt.plot(np.zeros(2)+70,[-1000,250000],color='purple')
plt.xticks(np.arange(0,100,7),['24 Feb','2 Mar','9 Mar','16 Mar','23 Mar','30 Mar','6 Apr','13 Apr','20 Apr','27 Apr','4 Mag','11 Mag','18 Mag','25 Mag','1 Giu'],rotation=30)
plt.xlim(0,100)
plt.ylim(100,ydata_inf.max()*1.5)
#plt.yscale('log')
plt.annotate("Lockdown", xy=(14,10000), xytext=(3,40000), arrowprops=dict(arrowstyle="->"),fontsize=13)
plt.xlabel('Data')
plt.ylabel('Counter')
plt.legend()
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('output3/fit_con_incertezza_4par.png',dpi=300)
plt.show()  
'''
# Out:
# '\n# 3 parameter fit for the active infected\n\ndef optimizer_adv(R0,gamma,tau,t_thresh):\n    \n    asympt=3\n    \n    fin_result_updated=SIR_2(6*10**7,R0*gamma,gamma,tau,t_thresh,I0=asympt*ydata_inf[0])\n    i_vec=fin_result_updated[2]/asympt\n    \n    pesi=np.exp(-np.arange(len(ydata_inf))/7)    # \n    pesi=pesi[::-1]\n    \n    accuracy=np.sum((ydata_inf-i_vec[0:len(ydata_inf)])**2)   #mean squared error. This is used for the optimization\n    \n    errperc=np.mean(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100\n    stdperc=np.std(np.abs((ydata_inf-i_vec[0:len(ydata_inf)])/ydata_inf))*100\n    \n    return accuracy,errperc,stdperc\n\n\n# grid on 3 parameters\nR0grid=np.linspace(3,9,10)\ngammagrid=np.linspace(0,0.2,10)\ntaugrid=np.linspace(23,35,10)\nttreshgrid=np.linspace(0,15,5)\n\nres_scan=[]\ncounter=0\ncounter2=0\ncycle_tot=len(R0grid)*len(gammagrid)*len(taugrid)*len(ttreshgrid)\n\ntime1=pctime.time()\n\n# minimization\n\nfor r in R0grid:\n    for g in gammagrid:\n        for tau in taugrid:\n            for tt in ttreshgrid:\n                opt_res=optimizer_adv(r,g,tau,tt)\n                res_scan.append([r,g,tau,tt,opt_res[0],opt_res[1],opt_res[2]])\n                counter=counter+1\n                counter2=counter2+1\n                if counter2==cycle_tot/10:\n                    time2=pctime.time()\n                    remtime=round((time2-time1)/counter*(cycle_tot-counter),1)\n                    print(\'completed \',round(counter/cycle_tot*100,1),\'%. Remaining time \',remtime,\'sec\')\n                    counter2=0\n        \nres_scan=np.array(res_scan)\n\ndf_res_scan=pd.DataFrame(res_scan)\ndf_res_scan.columns=[\'R0\',\'gamma\',\'tau\',\'t_thresh\',\'MSE\',\'mean err%\',\'std err%\']\n\nprint(df_res_scan.sort_values(by=\'MSE\'))\n\npar_ideal=np.array(df_res_scan.sort_values(by=\'MSE\').iloc[0,0:])\n\nfin_result_updated=SIR_2(6*10**7,par_ideal[0]*par_ideal[1],par_ideal[1],par_ideal[2],t_thresh=par_ideal[3],I0=3*ydata_inf[0])\n\nt=fin_result_updated[0]\ns_vec=fin_result_updated[1]\ni_vec=fin_result_updated[2]\nr_vec=fin_result_updated[3]\n\nplt.figure(figsize=(7,5))\nplt.plot(np.arange(len(ydata_inf)),ydata_inf,color=\'red\',linestyle=\'None\',marker=\'.\',label=\'Infetti attivi (dati)\')\nplt.plot(t, i_vec/3, label=\'Infetti attivi (modello, best-fit)\',color=\'red\',linestyle=\'--\')\nplt.fill_between(t, i_vec*(1+par_ideal[5]/100*2)/3,i_vec*(1-par_ideal[5]/100*2)/3, label=\'Infetti attivi (modello, 95% C.L.)\',color=\'red\',alpha=.2)\nplt.plot(np.zeros(2)+70,[-1000,250000],color=\'purple\')\nplt.xticks(np.arange(0,100,7),[\'24 Feb\',\'2 Mar\',\'9 Mar\',\'16 Mar\',\'23 Mar\',\'30 Mar\',\'6 Apr\',\'13 Apr\',\'20 Apr\',\'27 Apr\',\'4 Mag\',\'11 Mag\',\'18 Mag\',\'25 Mag\',\'1 Giu\'],rotation=30)\nplt.xlim(0,100)\nplt.ylim(100,ydata_inf.max()*1.5)\n#plt.yscale(\'log\')\nplt.annotate("Lockdown", xy=(14,10000), xytext=(3,40000), arrowprops=dict(arrowstyle="->"),fontsize=13)\nplt.xlabel(\'Data\')\nplt.ylabel(\'Counter\')\nplt.legend()\nplt.grid(color=\'gray\', linestyle=\'--\', linewidth=0.5)\nplt.tight_layout()\nplt.savefig(\'output3/fit_con_incertezza_4par.png\',dpi=300)\nplt.show()  \n'

# %%
np.savetxt('output/ydata_inf.txt',ydata_inf)

np.array(ydata_inf)[-1]
# Out:
# 14621

# %%
def perc(a,b):
    res_perc=int((a/b-1)*100)
    return res_perc

# %%
print('Infetti al 3 Maggio ',ydata_inf[-1])
print('Infetti al lockdown ',ydata_inf[14],'+',perc(ydata_inf[-1],ydata_inf[14]),'%')
print('Infetti massimo (20 Aprile)',ydata_inf.max(),perc(ydata_inf[-1],ydata_inf.max()),'%')
print('Terapia intensiva oggi ',data.iloc[-1,3])
print('Terapia intensiva al lockdown ',data.iloc[14,3],'+',perc(data.iloc[-1,3],data.iloc[14,3]),'%')
print('FTSEMib oggi 17690')
print('FTSEMib lockdown 18475, -4%')
print('FTSEMib 19 Febbraio 25477, -30%')
# Out:
# Infetti al 3 Maggio  14621
# Infetti al lockdown  7985 + 83 %
# Infetti massimo (20 Aprile) 108257 -86 %
# Terapia intensiva oggi  71
# Terapia intensiva al lockdown  733 + -90 %
# FTSEMib oggi 17690
# FTSEMib lockdown 18475, -4%
# FTSEMib 19 Febbraio 25477, -30%

# %%
ydata_inf[-1]
# Out:
# 14621
