# %%
# importing packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 1. Import data

# %%
# importing files

labels=pd.read_csv('train_labels.csv')
values=pd.read_csv('train_values.csv')

# %%
labels.head()
# Out:
#   patient_id  heart_disease_present
# 0     0z64un                      0
# 1     ryoo3j                      0
# 2     yt1s1x                      1
# 3     l2xjde                      1
# 4     oyt4ek                      0

# %%
values.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# 3                                     0                    0
# 4                                     0                    2
#
#    serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  sex  age  \
# 0                          308                       0.0    1   45
# 1                          214                       1.6    0   54
# 2                          304                       0.0    1   77
# 3                          223                       0.0    1   40
# 4                          270                       4.2    1   59
#
#    max_heart_rate_achieved  exercise_induced_angina
# 0                      170                        0
# 1                      158                        0
# 2                      162                        1
# 3                      181                        0
# 4                      145                        0

# %%
values.shape    #there are 14 variables and 180 entries
# Out:
# (180, 14)

# %%
plt.hist(labels['heart_disease_present'])
plt.xticks([0,1],['No','Yes'])
plt.grid()
plt.show()

# %% [markdown]
# # 2. Data pre-processing

# %%
labels.set_index('patient_id',inplace=True)
values.set_index('patient_id',inplace=True)

# %%
df_train=values.join(labels,on=values.index)

df_train.head()
# Out:
#             slope_of_peak_exercise_st_segment               thal  \
# patient_id
# 0z64un                                      1             normal
# ryoo3j                                      2             normal
# yt1s1x                                      1             normal
# l2xjde                                      1  reversible_defect
# oyt4ek                                      3  reversible_defect
#
#             resting_blood_pressure  chest_pain_type  num_major_vessels  \
# patient_id
# 0z64un                         128                2                  0
# ryoo3j                         110                3                  0
# yt1s1x                         125                4                  3
# l2xjde                         152                4                  0
# oyt4ek                         178                1                  0
#
#             fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# patient_id
# 0z64un                                         0                    2
# ryoo3j                                         0                    0
# yt1s1x                                         0                    2
# l2xjde                                         0                    0
# oyt4ek                                         0                    2
#
#             serum_cholesterol_mg_per_dl  oldpeak_eq_st_depression  sex  age  \
# patient_id
# 0z64un                              308                       0.0    1   45
# ryoo3j                              214                       1.6    0   54
# yt1s1x                              304                       0.0    1   77
# l2xjde                              223                       0.0    1   40
# oyt4ek                              270                       4.2    1   59
#
#             max_heart_rate_achieved  exercise_induced_angina  \
# patient_id
# 0z64un                          170                        0
# ryoo3j                          158                        0
# yt1s1x                          162                        1
# l2xjde                          181                        0
# oyt4ek                          145                        0
#
#             heart_disease_present
# patient_id
# 0z64un                          0
# ryoo3j                          0
# yt1s1x                          1
# l2xjde                          1
# oyt4ek                          0

# %%
pd.get_dummies(df_train['thal'])
# Out:
#             fixed_defect  normal  reversible_defect
# patient_id
# 0z64un                 0       1                  0
# ryoo3j                 0       1                  0
# yt1s1x                 0       1                  0
# l2xjde                 0       0                  1
# oyt4ek                 0       0                  1
# ...                  ...     ...                ...
# 5qfar3                 0       0                  1
# 2s2b1f                 0       1                  0
# nsd00i                 0       0                  1
# 0xw93k                 0       1                  0
# 2nx10r                 0       1                  0
#
# [180 rows x 3 columns]

# %%
df_train[['fixed_defect','normal','reversible_defect']]=pd.get_dummies(df_train['thal'])

df_train.drop(['thal','fixed_defect'],axis=1,inplace=True)

# %%
df_train.shape
# Out:
# (180, 15)

# %%
df_train.info()   #all the variables are integer of float number. The patient ID is not a variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, 0z64un to 2nx10r
# Data columns (total 15 columns):
# slope_of_peak_exercise_st_segment       180 non-null int64
# resting_blood_pressure                  180 non-null int64
# chest_pain_type                         180 non-null int64
# num_major_vessels                       180 non-null int64
# fasting_blood_sugar_gt_120_mg_per_dl    180 non-null int64
# resting_ekg_results                     180 non-null int64
# serum_cholesterol_mg_per_dl             180 non-null int64
# oldpeak_eq_st_depression                180 non-null float64
# sex                                     180 non-null int64
# age                                     180 non-null int64
# max_heart_rate_achieved                 180 non-null int64
# exercise_induced_angina                 180 non-null int64
# heart_disease_present                   180 non-null int64
# normal                                  180 non-null uint8
# reversible_defect                       180 non-null uint8
# dtypes: float64(1), int64(12), uint8(2)
# memory usage: 20.0+ KB

# %% [markdown]
# # 3. Data visualization

# %%
import seaborn as sns

# %%
sns.boxplot(x='heart_disease_present',y='resting_blood_pressure',data=df_train)
plt.show()

# %%
sns.boxplot(x='heart_disease_present',y='serum_cholesterol_mg_per_dl',data=df_train)
plt.show()

# %%
sns.boxplot(x='heart_disease_present',y='age',data=df_train)
plt.show()

# %%
df_train_subset=df_train[['serum_cholesterol_mg_per_dl','age','resting_blood_pressure']]
sns.pairplot(df_train_subset)
plt.show()

# %% [markdown]
# # 4. Preparing the dataset for the ML algorithm

# %%
# definition of the array characterizing the training set

X=np.array(df_train.drop('heart_disease_present',axis=1))
y=df_train['heart_disease_present']   # I save in y my training results

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler=StandardScaler()
X_std=scaler.fit_transform(X)
#X_std=X

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2,random_state=42,stratify=y)

y_train_dumm=pd.get_dummies(y_train)
y_test_dumm=pd.get_dummies(y_test)

from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',np.unique(y_train),y_train)

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=100)

rf.fit(X,y)

feature_importance=rf.feature_importances_
print(feature_importance)
name_features=df_train.drop('heart_disease_present',axis=1).columns

#plt.bar(x=name_features,y=rf.feature_importances_)

plt.bar(np.arange(len(feature_importance)),feature_importance)
plt.xticks(np.arange(len(feature_importance)),name_features,rotation=90)
plt.ylabel('Feature importance')
plt.show()
# Out:
# [0.04583902 0.07231158 0.0988688  0.0773373  0.00940278 0.02193473
#  0.08040437 0.10760924 0.03460032 0.08809196 0.11453683 0.04416491
#  0.10094213 0.10395602]

# %% [markdown]
# # 5. Machine learning algorithm

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.models import load_model
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.layers import Dropout

# Here I build the neural network
ncols=X_train.shape[1]

model=Sequential()

# 1th hidden layer
model.add(Dense(100,input_shape=(ncols,),activation='relu'))
model.add(Dropout(0.2))

# 2th hidden layer
model.add(Dense(100,activation='relu'))
model.add(Dropout(0.2))

# output layer
model.add(Dense(2,activation='sigmoid'))

# optimizer
#opt=SGD(lr=0.02,momentum=0.5, nesterov=False)

# compile
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# monitor
early_stopping_monitor = EarlyStopping(patience=200,monitor='val_acc')
checkpoint=ModelCheckpoint(filepath='best_model.hdf5',save_weights_only=False,monitor='val_acc',mode='auto',save_best_only=True,verbose=1)


# fit the model
history=model.fit(X_train, y_train_dumm ,epochs=200,validation_data=(X_test,y_test_dumm),callbacks=[early_stopping_monitor,checkpoint],class_weight=class_weights)
print("Loss function: " + model.loss)
# Out:
# Train on 144 samples, validate on 36 samples
# Epoch 1/200
# 144/144 [==============================] - 10s 68ms/step - loss: 0.7423 - acc: 0.4653 - val_loss: 0.6621 - val_acc: 0.5556
#
# Epoch 00001: val_acc improved from -inf to 0.55556, saving model to best_model.hdf5
# Epoch 2/200
# 144/144 [==============================] - 0s 878us/step - loss: 0.6608 - acc: 0.6319 - val_loss: 0.5933 - val_acc: 0.7500
#
# Epoch 00002: val_acc improved from 0.55556 to 0.75000, saving model to best_model.hdf5
# Epoch 3/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.6225 - acc: 0.6979 - val_loss: 0.5369 - val_acc: 0.8056
#
# Epoch 00003: val_acc improved from 0.75000 to 0.80556, saving model to best_model.hdf5
# Epoch 4/200
# 144/144 [==============================] - 0s 659us/step - loss: 0.5463 - acc: 0.8056 - val_loss: 0.4898 - val_acc: 0.8056
#
# Epoch 00004: val_acc did not improve from 0.80556
# Epoch 5/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.5197 - acc: 0.8229 - val_loss: 0.4500 - val_acc: 0.8056
#
# Epoch 00005: val_acc did not improve from 0.80556
# Epoch 6/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.4849 - acc: 0.8194 - val_loss: 0.4209 - val_acc: 0.8194
#
# Epoch 00006: val_acc improved from 0.80556 to 0.81944, saving model to best_model.hdf5
# Epoch 7/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.4373 - acc: 0.8472 - val_loss: 0.3968 - val_acc: 0.8194
#
# Epoch 00007: val_acc did not improve from 0.81944
# Epoch 8/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.4233 - acc: 0.8438 - val_loss: 0.3778 - val_acc: 0.8194
#
# Epoch 00008: val_acc did not improve from 0.81944
# Epoch 9/200
# 144/144 [==============================] - 0s 938us/step - loss: 0.4161 - acc: 0.8403 - val_loss: 0.3673 - val_acc: 0.8194
#
# Epoch 00009: val_acc did not improve from 0.81944
# Epoch 10/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3813 - acc: 0.8715 - val_loss: 0.3603 - val_acc: 0.8194
#
# Epoch 00010: val_acc did not improve from 0.81944
# Epoch 11/200
# 144/144 [==============================] - 0s 998us/step - loss: 0.3536 - acc: 0.8681 - val_loss: 0.3613 - val_acc: 0.8333
#
# Epoch 00011: val_acc improved from 0.81944 to 0.83333, saving model to best_model.hdf5
# Epoch 12/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.3709 - acc: 0.8507 - val_loss: 0.3611 - val_acc: 0.8333
#
# Epoch 00012: val_acc did not improve from 0.83333
# Epoch 13/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.3579 - acc: 0.8646 - val_loss: 0.3625 - val_acc: 0.8333
#
# Epoch 00013: val_acc did not improve from 0.83333
# Epoch 14/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3410 - acc: 0.8681 - val_loss: 0.3650 - val_acc: 0.8333
#
# Epoch 00014: val_acc did not improve from 0.83333
# Epoch 15/200
# 144/144 [==============================] - 0s 940us/step - loss: 0.3515 - acc: 0.8681 - val_loss: 0.3665 - val_acc: 0.8333
#
# Epoch 00015: val_acc did not improve from 0.83333
# Epoch 16/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3338 - acc: 0.8576 - val_loss: 0.3674 - val_acc: 0.8333
#
# Epoch 00016: val_acc did not improve from 0.83333
# Epoch 17/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3465 - acc: 0.8681 - val_loss: 0.3671 - val_acc: 0.8472
#
# Epoch 00017: val_acc improved from 0.83333 to 0.84722, saving model to best_model.hdf5
# Epoch 18/200
# 144/144 [==============================] - 0s 958us/step - loss: 0.3286 - acc: 0.8681 - val_loss: 0.3638 - val_acc: 0.8472
#
# Epoch 00018: val_acc did not improve from 0.84722
# Epoch 19/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2908 - acc: 0.9028 - val_loss: 0.3667 - val_acc: 0.8472
#
# Epoch 00019: val_acc did not improve from 0.84722
# Epoch 20/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3198 - acc: 0.8889 - val_loss: 0.3727 - val_acc: 0.8472
#
# Epoch 00020: val_acc did not improve from 0.84722
# Epoch 21/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.3072 - acc: 0.8854 - val_loss: 0.3688 - val_acc: 0.8472
#
# Epoch 00021: val_acc did not improve from 0.84722
# Epoch 22/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.3139 - acc: 0.8715 - val_loss: 0.3719 - val_acc: 0.8472
#
# Epoch 00022: val_acc did not improve from 0.84722
# Epoch 23/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2800 - acc: 0.8993 - val_loss: 0.3775 - val_acc: 0.8333
#
# Epoch 00023: val_acc did not improve from 0.84722
# Epoch 24/200
# 144/144 [==============================] - 0s 801us/step - loss: 0.2944 - acc: 0.8958 - val_loss: 0.3813 - val_acc: 0.8333
#
# Epoch 00024: val_acc did not improve from 0.84722
# Epoch 25/200
# 144/144 [==============================] - 0s 665us/step - loss: 0.2656 - acc: 0.9062 - val_loss: 0.3871 - val_acc: 0.8194
#
# Epoch 00025: val_acc did not improve from 0.84722
# Epoch 26/200
# 144/144 [==============================] - 0s 647us/step - loss: 0.2673 - acc: 0.8924 - val_loss: 0.3882 - val_acc: 0.8194
#
# Epoch 00026: val_acc did not improve from 0.84722
# Epoch 27/200
# 144/144 [==============================] - 0s 768us/step - loss: 0.2652 - acc: 0.8993 - val_loss: 0.3863 - val_acc: 0.8194
#
# Epoch 00027: val_acc did not improve from 0.84722
# Epoch 28/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2715 - acc: 0.8924 - val_loss: 0.3825 - val_acc: 0.8472
#
# Epoch 00028: val_acc did not improve from 0.84722
# Epoch 29/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.2589 - acc: 0.8889 - val_loss: 0.3788 - val_acc: 0.8472
#
# Epoch 00029: val_acc did not improve from 0.84722
# Epoch 30/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2461 - acc: 0.9028 - val_loss: 0.3664 - val_acc: 0.8472
#
# Epoch 00030: val_acc did not improve from 0.84722
# Epoch 31/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.2475 - acc: 0.9062 - val_loss: 0.3639 - val_acc: 0.8611
#
# Epoch 00031: val_acc improved from 0.84722 to 0.86111, saving model to best_model.hdf5
# Epoch 32/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2447 - acc: 0.8993 - val_loss: 0.3636 - val_acc: 0.8611
#
# Epoch 00032: val_acc did not improve from 0.86111
# Epoch 33/200
# 144/144 [==============================] - 0s 717us/step - loss: 0.2391 - acc: 0.8924 - val_loss: 0.3774 - val_acc: 0.8472
#
# Epoch 00033: val_acc did not improve from 0.86111
# Epoch 34/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2092 - acc: 0.9167 - val_loss: 0.3856 - val_acc: 0.8472
#
# Epoch 00034: val_acc did not improve from 0.86111
# Epoch 35/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2333 - acc: 0.9167 - val_loss: 0.3808 - val_acc: 0.8472
#
# Epoch 00035: val_acc did not improve from 0.86111
# Epoch 36/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2457 - acc: 0.9097 - val_loss: 0.3786 - val_acc: 0.8472
#
# Epoch 00036: val_acc did not improve from 0.86111
# Epoch 37/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2296 - acc: 0.9271 - val_loss: 0.3903 - val_acc: 0.8611
#
# Epoch 00037: val_acc did not improve from 0.86111
# Epoch 38/200
# 144/144 [==============================] - 0s 868us/step - loss: 0.2273 - acc: 0.9167 - val_loss: 0.4006 - val_acc: 0.8750
#
# Epoch 00038: val_acc improved from 0.86111 to 0.87500, saving model to best_model.hdf5
# Epoch 39/200
# 144/144 [==============================] - 0s 3ms/step - loss: 0.2093 - acc: 0.8958 - val_loss: 0.4103 - val_acc: 0.8333
#
# Epoch 00039: val_acc did not improve from 0.87500
# Epoch 40/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1939 - acc: 0.9306 - val_loss: 0.4112 - val_acc: 0.8472
#
# Epoch 00040: val_acc did not improve from 0.87500
# Epoch 41/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2145 - acc: 0.9097 - val_loss: 0.3995 - val_acc: 0.8611
#
# Epoch 00041: val_acc did not improve from 0.87500
# Epoch 42/200
# 144/144 [==============================] - 0s 796us/step - loss: 0.1983 - acc: 0.9271 - val_loss: 0.3759 - val_acc: 0.8750
#
# Epoch 00042: val_acc did not improve from 0.87500
# Epoch 43/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2045 - acc: 0.9132 - val_loss: 0.3576 - val_acc: 0.8750
#
# Epoch 00043: val_acc did not improve from 0.87500
# Epoch 44/200
# 144/144 [==============================] - 0s 962us/step - loss: 0.1886 - acc: 0.9201 - val_loss: 0.3620 - val_acc: 0.8750
#
# Epoch 00044: val_acc did not improve from 0.87500
# Epoch 45/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.2077 - acc: 0.9201 - val_loss: 0.3834 - val_acc: 0.8472
#
# Epoch 00045: val_acc did not improve from 0.87500
# Epoch 46/200
# 144/144 [==============================] - 0s 865us/step - loss: 0.1869 - acc: 0.9271 - val_loss: 0.4149 - val_acc: 0.8889
#
# Epoch 00046: val_acc improved from 0.87500 to 0.88889, saving model to best_model.hdf5
# Epoch 47/200
# 144/144 [==============================] - 0s 732us/step - loss: 0.1785 - acc: 0.9444 - val_loss: 0.4349 - val_acc: 0.8889
#
# Epoch 00047: val_acc did not improve from 0.88889
# Epoch 48/200
# 144/144 [==============================] - 0s 661us/step - loss: 0.1505 - acc: 0.9549 - val_loss: 0.4338 - val_acc: 0.8889
#
# Epoch 00048: val_acc did not improve from 0.88889
# Epoch 49/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1758 - acc: 0.9306 - val_loss: 0.4337 - val_acc: 0.8889
#
# Epoch 00049: val_acc did not improve from 0.88889
# Epoch 50/200
# 144/144 [==============================] - 0s 899us/step - loss: 0.1821 - acc: 0.9410 - val_loss: 0.4498 - val_acc: 0.8750
#
# Epoch 00050: val_acc did not improve from 0.88889
# Epoch 51/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1593 - acc: 0.9375 - val_loss: 0.4699 - val_acc: 0.8611
#
# Epoch 00051: val_acc did not improve from 0.88889
# Epoch 52/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1735 - acc: 0.9340 - val_loss: 0.4739 - val_acc: 0.8472
#
# Epoch 00052: val_acc did not improve from 0.88889
# Epoch 53/200
# 144/144 [==============================] - 0s 871us/step - loss: 0.1391 - acc: 0.9549 - val_loss: 0.4618 - val_acc: 0.8750
#
# Epoch 00053: val_acc did not improve from 0.88889
# Epoch 54/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1644 - acc: 0.9479 - val_loss: 0.4488 - val_acc: 0.8750
#
# Epoch 00054: val_acc did not improve from 0.88889
# Epoch 55/200
# 144/144 [==============================] - 0s 722us/step - loss: 0.1443 - acc: 0.9410 - val_loss: 0.4455 - val_acc: 0.8889
#
# Epoch 00055: val_acc did not improve from 0.88889
# Epoch 56/200
# 144/144 [==============================] - 0s 980us/step - loss: 0.1638 - acc: 0.9375 - val_loss: 0.4477 - val_acc: 0.8889
#
# Epoch 00056: val_acc did not improve from 0.88889
# Epoch 57/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1358 - acc: 0.9549 - val_loss: 0.4544 - val_acc: 0.8750
#
# Epoch 00057: val_acc did not improve from 0.88889
# Epoch 58/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1317 - acc: 0.9583 - val_loss: 0.4679 - val_acc: 0.8611
#
# Epoch 00058: val_acc did not improve from 0.88889
# Epoch 59/200
# 144/144 [==============================] - 0s 821us/step - loss: 0.1299 - acc: 0.9618 - val_loss: 0.4884 - val_acc: 0.8611
#
# Epoch 00059: val_acc did not improve from 0.88889
# Epoch 60/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1453 - acc: 0.9375 - val_loss: 0.4910 - val_acc: 0.8611
#
# Epoch 00060: val_acc did not improve from 0.88889
# Epoch 61/200
# 144/144 [==============================] - 0s 968us/step - loss: 0.1118 - acc: 0.9757 - val_loss: 0.4979 - val_acc: 0.8611
#
# Epoch 00061: val_acc did not improve from 0.88889
# Epoch 62/200
# 144/144 [==============================] - 0s 668us/step - loss: 0.1313 - acc: 0.9618 - val_loss: 0.5047 - val_acc: 0.8611
#
# Epoch 00062: val_acc did not improve from 0.88889
# Epoch 63/200
# 144/144 [==============================] - 0s 603us/step - loss: 0.1106 - acc: 0.9722 - val_loss: 0.5136 - val_acc: 0.8472
#
# Epoch 00063: val_acc did not improve from 0.88889
# Epoch 64/200
# 144/144 [==============================] - 0s 657us/step - loss: 0.1348 - acc: 0.9444 - val_loss: 0.5228 - val_acc: 0.8472
#
# Epoch 00064: val_acc did not improve from 0.88889
# Epoch 65/200
# 144/144 [==============================] - 0s 668us/step - loss: 0.1196 - acc: 0.9549 - val_loss: 0.4996 - val_acc: 0.8611
#
# Epoch 00065: val_acc did not improve from 0.88889
# Epoch 66/200
# 144/144 [==============================] - 0s 698us/step - loss: 0.1402 - acc: 0.9340 - val_loss: 0.4952 - val_acc: 0.8611
#
# Epoch 00066: val_acc did not improve from 0.88889
# Epoch 67/200
# 144/144 [==============================] - 0s 551us/step - loss: 0.1250 - acc: 0.9618 - val_loss: 0.5021 - val_acc: 0.8611
#
# Epoch 00067: val_acc did not improve from 0.88889
# Epoch 68/200
# 144/144 [==============================] - 0s 725us/step - loss: 0.1169 - acc: 0.9688 - val_loss: 0.5040 - val_acc: 0.8611
#
# Epoch 00068: val_acc did not improve from 0.88889
# Epoch 69/200
# 144/144 [==============================] - 0s 815us/step - loss: 0.1316 - acc: 0.9514 - val_loss: 0.5037 - val_acc: 0.8611
#
# Epoch 00069: val_acc did not improve from 0.88889
# Epoch 70/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1132 - acc: 0.9618 - val_loss: 0.5139 - val_acc: 0.8611
#
# Epoch 00070: val_acc did not improve from 0.88889
# Epoch 71/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1270 - acc: 0.9444 - val_loss: 0.5176 - val_acc: 0.8333
#
# Epoch 00071: val_acc did not improve from 0.88889
# Epoch 72/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1244 - acc: 0.9514 - val_loss: 0.5128 - val_acc: 0.8333
#
# Epoch 00072: val_acc did not improve from 0.88889
# Epoch 73/200
# 144/144 [==============================] - 0s 780us/step - loss: 0.1329 - acc: 0.9618 - val_loss: 0.5169 - val_acc: 0.8333
#
# Epoch 00073: val_acc did not improve from 0.88889
# Epoch 74/200
# 144/144 [==============================] - 0s 920us/step - loss: 0.0994 - acc: 0.9722 - val_loss: 0.5166 - val_acc: 0.8333
#
# Epoch 00074: val_acc did not improve from 0.88889
# Epoch 75/200
# 144/144 [==============================] - 0s 792us/step - loss: 0.1056 - acc: 0.9549 - val_loss: 0.5297 - val_acc: 0.8333
#
# Epoch 00075: val_acc did not improve from 0.88889
# Epoch 76/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0890 - acc: 0.9757 - val_loss: 0.5733 - val_acc: 0.8333
#
# Epoch 00076: val_acc did not improve from 0.88889
# Epoch 77/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.1080 - acc: 0.9549 - val_loss: 0.6123 - val_acc: 0.8194
#
# Epoch 00077: val_acc did not improve from 0.88889
# Epoch 78/200
# 144/144 [==============================] - 0s 961us/step - loss: 0.1105 - acc: 0.9583 - val_loss: 0.6130 - val_acc: 0.8194
#
# Epoch 00078: val_acc did not improve from 0.88889
# Epoch 79/200
# 144/144 [==============================] - 0s 967us/step - loss: 0.0955 - acc: 0.9688 - val_loss: 0.6141 - val_acc: 0.8194
#
# Epoch 00079: val_acc did not improve from 0.88889
# Epoch 80/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0888 - acc: 0.9792 - val_loss: 0.6102 - val_acc: 0.8194
#
# Epoch 00080: val_acc did not improve from 0.88889
# Epoch 81/200
# 144/144 [==============================] - 0s 623us/step - loss: 0.0872 - acc: 0.9653 - val_loss: 0.5794 - val_acc: 0.8333
#
# Epoch 00081: val_acc did not improve from 0.88889
# Epoch 82/200
# 144/144 [==============================] - 0s 545us/step - loss: 0.0783 - acc: 0.9757 - val_loss: 0.5675 - val_acc: 0.8472
#
# Epoch 00082: val_acc did not improve from 0.88889
# Epoch 83/200
# 144/144 [==============================] - 0s 672us/step - loss: 0.0920 - acc: 0.9618 - val_loss: 0.5720 - val_acc: 0.8472
#
# Epoch 00083: val_acc did not improve from 0.88889
# Epoch 84/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0670 - acc: 0.9826 - val_loss: 0.6154 - val_acc: 0.8194
#
# Epoch 00084: val_acc did not improve from 0.88889
# Epoch 85/200
# 144/144 [==============================] - 0s 909us/step - loss: 0.0912 - acc: 0.9722 - val_loss: 0.6498 - val_acc: 0.8194
#
# Epoch 00085: val_acc did not improve from 0.88889
# Epoch 86/200
# 144/144 [==============================] - 0s 731us/step - loss: 0.0740 - acc: 0.9792 - val_loss: 0.6619 - val_acc: 0.8194
#
# Epoch 00086: val_acc did not improve from 0.88889
# Epoch 87/200
# 144/144 [==============================] - 0s 988us/step - loss: 0.0649 - acc: 0.9757 - val_loss: 0.6559 - val_acc: 0.8333
#
# Epoch 00087: val_acc did not improve from 0.88889
# Epoch 88/200
# 144/144 [==============================] - 0s 930us/step - loss: 0.0821 - acc: 0.9688 - val_loss: 0.6765 - val_acc: 0.8194
#
# Epoch 00088: val_acc did not improve from 0.88889
# Epoch 89/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0715 - acc: 0.9792 - val_loss: 0.6812 - val_acc: 0.8194
#
# Epoch 00089: val_acc did not improve from 0.88889
# Epoch 90/200
# 144/144 [==============================] - 0s 889us/step - loss: 0.0658 - acc: 0.9792 - val_loss: 0.6616 - val_acc: 0.8194
#
# Epoch 00090: val_acc did not improve from 0.88889
# Epoch 91/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0738 - acc: 0.9792 - val_loss: 0.6472 - val_acc: 0.8333
#
# Epoch 00091: val_acc did not improve from 0.88889
# Epoch 92/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0640 - acc: 0.9896 - val_loss: 0.6412 - val_acc: 0.8333
#
# Epoch 00092: val_acc did not improve from 0.88889
# Epoch 93/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0766 - acc: 0.9792 - val_loss: 0.6488 - val_acc: 0.8333
#
# Epoch 00093: val_acc did not improve from 0.88889
# Epoch 94/200
# 144/144 [==============================] - 0s 969us/step - loss: 0.0599 - acc: 0.9861 - val_loss: 0.6606 - val_acc: 0.8333
#
# Epoch 00094: val_acc did not improve from 0.88889
# Epoch 95/200
# 144/144 [==============================] - 0s 979us/step - loss: 0.0730 - acc: 0.9757 - val_loss: 0.6734 - val_acc: 0.8333
#
# Epoch 00095: val_acc did not improve from 0.88889
# Epoch 96/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0755 - acc: 0.9826 - val_loss: 0.7167 - val_acc: 0.8194
#
# Epoch 00096: val_acc did not improve from 0.88889
# Epoch 97/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0764 - acc: 0.9722 - val_loss: 0.7388 - val_acc: 0.8194
#
# Epoch 00097: val_acc did not improve from 0.88889
# Epoch 98/200
# 144/144 [==============================] - 0s 583us/step - loss: 0.0584 - acc: 0.9861 - val_loss: 0.7331 - val_acc: 0.8333
#
# Epoch 00098: val_acc did not improve from 0.88889
# Epoch 99/200
# 144/144 [==============================] - 0s 629us/step - loss: 0.0576 - acc: 0.9826 - val_loss: 0.7359 - val_acc: 0.8333
#
# Epoch 00099: val_acc did not improve from 0.88889
# Epoch 100/200
# 144/144 [==============================] - 0s 622us/step - loss: 0.0586 - acc: 0.9826 - val_loss: 0.7517 - val_acc: 0.8333
#
# Epoch 00100: val_acc did not improve from 0.88889
# Epoch 101/200
# 144/144 [==============================] - 0s 891us/step - loss: 0.0597 - acc: 0.9896 - val_loss: 0.7442 - val_acc: 0.8333
#
# Epoch 00101: val_acc did not improve from 0.88889
# Epoch 102/200
# 144/144 [==============================] - 0s 872us/step - loss: 0.0701 - acc: 0.9653 - val_loss: 0.7008 - val_acc: 0.8333
#
# Epoch 00102: val_acc did not improve from 0.88889
# Epoch 103/200
# 144/144 [==============================] - 0s 975us/step - loss: 0.0615 - acc: 0.9757 - val_loss: 0.6831 - val_acc: 0.8194
#
# Epoch 00103: val_acc did not improve from 0.88889
# Epoch 104/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0445 - acc: 0.9861 - val_loss: 0.6736 - val_acc: 0.8194
#
# Epoch 00104: val_acc did not improve from 0.88889
# Epoch 105/200
# 144/144 [==============================] - 0s 796us/step - loss: 0.0531 - acc: 0.9792 - val_loss: 0.7075 - val_acc: 0.8194
#
# Epoch 00105: val_acc did not improve from 0.88889
# Epoch 106/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0454 - acc: 0.9896 - val_loss: 0.7473 - val_acc: 0.8333
#
# Epoch 00106: val_acc did not improve from 0.88889
# Epoch 107/200
# 144/144 [==============================] - 0s 727us/step - loss: 0.0599 - acc: 0.9757 - val_loss: 0.7377 - val_acc: 0.8333
#
# Epoch 00107: val_acc did not improve from 0.88889
# Epoch 108/200
# 144/144 [==============================] - 0s 928us/step - loss: 0.0580 - acc: 0.9792 - val_loss: 0.7062 - val_acc: 0.8194
#
# Epoch 00108: val_acc did not improve from 0.88889
# Epoch 109/200
# 144/144 [==============================] - 0s 927us/step - loss: 0.0389 - acc: 0.9931 - val_loss: 0.7068 - val_acc: 0.8194
#
# Epoch 00109: val_acc did not improve from 0.88889
# Epoch 110/200
# 144/144 [==============================] - 0s 840us/step - loss: 0.0422 - acc: 0.9861 - val_loss: 0.7065 - val_acc: 0.8056
#
# Epoch 00110: val_acc did not improve from 0.88889
# Epoch 111/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0467 - acc: 0.9792 - val_loss: 0.7141 - val_acc: 0.8194
#
# Epoch 00111: val_acc did not improve from 0.88889
# Epoch 112/200
# 144/144 [==============================] - 0s 675us/step - loss: 0.0507 - acc: 0.9792 - val_loss: 0.6744 - val_acc: 0.8194
#
# Epoch 00112: val_acc did not improve from 0.88889
# Epoch 113/200
# 144/144 [==============================] - 0s 719us/step - loss: 0.0356 - acc: 0.9931 - val_loss: 0.6856 - val_acc: 0.8194
#
# Epoch 00113: val_acc did not improve from 0.88889
# Epoch 114/200
# 144/144 [==============================] - 0s 983us/step - loss: 0.0555 - acc: 0.9826 - val_loss: 0.7135 - val_acc: 0.8333
#
# Epoch 00114: val_acc did not improve from 0.88889
# Epoch 115/200
# 144/144 [==============================] - 0s 884us/step - loss: 0.0597 - acc: 0.9792 - val_loss: 0.7538 - val_acc: 0.8333
#
# Epoch 00115: val_acc did not improve from 0.88889
# Epoch 116/200
# 144/144 [==============================] - 0s 819us/step - loss: 0.0362 - acc: 0.9931 - val_loss: 0.7971 - val_acc: 0.8333
#
# Epoch 00116: val_acc did not improve from 0.88889
# Epoch 117/200
# 144/144 [==============================] - 0s 901us/step - loss: 0.0467 - acc: 0.9896 - val_loss: 0.7887 - val_acc: 0.8333
#
# Epoch 00117: val_acc did not improve from 0.88889
# Epoch 118/200
# 144/144 [==============================] - 0s 791us/step - loss: 0.0434 - acc: 0.9896 - val_loss: 0.7798 - val_acc: 0.8333
#
# Epoch 00118: val_acc did not improve from 0.88889
# Epoch 119/200
# 144/144 [==============================] - 0s 891us/step - loss: 0.0490 - acc: 0.9861 - val_loss: 0.7809 - val_acc: 0.8333
#
# Epoch 00119: val_acc did not improve from 0.88889
# Epoch 120/200
# 144/144 [==============================] - 0s 950us/step - loss: 0.0449 - acc: 0.9931 - val_loss: 0.7490 - val_acc: 0.8333
#
# Epoch 00120: val_acc did not improve from 0.88889
# Epoch 121/200
# 144/144 [==============================] - 0s 929us/step - loss: 0.0633 - acc: 0.9826 - val_loss: 0.7404 - val_acc: 0.8333
#
# Epoch 00121: val_acc did not improve from 0.88889
# Epoch 122/200
# 144/144 [==============================] - 0s 823us/step - loss: 0.0484 - acc: 0.9861 - val_loss: 0.7690 - val_acc: 0.8333
#
# Epoch 00122: val_acc did not improve from 0.88889
# Epoch 123/200
# 144/144 [==============================] - 0s 2ms/step - loss: 0.0291 - acc: 0.9931 - val_loss: 0.7935 - val_acc: 0.8333
#
# Epoch 00123: val_acc did not improve from 0.88889
# Epoch 124/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0491 - acc: 0.9792 - val_loss: 0.8262 - val_acc: 0.8333
#
# Epoch 00124: val_acc did not improve from 0.88889
# Epoch 125/200
# 144/144 [==============================] - 0s 825us/step - loss: 0.0527 - acc: 0.9826 - val_loss: 0.8597 - val_acc: 0.8333
#
# Epoch 00125: val_acc did not improve from 0.88889
# Epoch 126/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0378 - acc: 0.9931 - val_loss: 0.8649 - val_acc: 0.8333
#
# Epoch 00126: val_acc did not improve from 0.88889
# Epoch 127/200
# 144/144 [==============================] - 0s 951us/step - loss: 0.0408 - acc: 0.9896 - val_loss: 0.8430 - val_acc: 0.8333
#
# Epoch 00127: val_acc did not improve from 0.88889
# Epoch 128/200
# 144/144 [==============================] - 0s 965us/step - loss: 0.0372 - acc: 1.0000 - val_loss: 0.8258 - val_acc: 0.8333
#
# Epoch 00128: val_acc did not improve from 0.88889
# Epoch 129/200
# 144/144 [==============================] - 0s 871us/step - loss: 0.0318 - acc: 0.9965 - val_loss: 0.7995 - val_acc: 0.8333
#
# Epoch 00129: val_acc did not improve from 0.88889
# Epoch 130/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0406 - acc: 0.9861 - val_loss: 0.8462 - val_acc: 0.8333
#
# Epoch 00130: val_acc did not improve from 0.88889
# Epoch 131/200
# 144/144 [==============================] - 0s 949us/step - loss: 0.0346 - acc: 0.9931 - val_loss: 0.8971 - val_acc: 0.8194
#
# Epoch 00131: val_acc did not improve from 0.88889
# Epoch 132/200
# 144/144 [==============================] - 0s 668us/step - loss: 0.0463 - acc: 0.9931 - val_loss: 0.9013 - val_acc: 0.8194
#
# Epoch 00132: val_acc did not improve from 0.88889
# Epoch 133/200
# 144/144 [==============================] - 0s 830us/step - loss: 0.0310 - acc: 0.9931 - val_loss: 0.8868 - val_acc: 0.8333
#
# Epoch 00133: val_acc did not improve from 0.88889
# Epoch 134/200
# 144/144 [==============================] - 0s 727us/step - loss: 0.0678 - acc: 0.9757 - val_loss: 0.8284 - val_acc: 0.8333
#
# Epoch 00134: val_acc did not improve from 0.88889
# Epoch 135/200
# 144/144 [==============================] - 0s 801us/step - loss: 0.0373 - acc: 0.9931 - val_loss: 0.8091 - val_acc: 0.8333
#
# Epoch 00135: val_acc did not improve from 0.88889
# Epoch 136/200
# 144/144 [==============================] - 0s 871us/step - loss: 0.0463 - acc: 0.9861 - val_loss: 0.8183 - val_acc: 0.8333
#
# Epoch 00136: val_acc did not improve from 0.88889
# Epoch 137/200
# 144/144 [==============================] - 0s 978us/step - loss: 0.0367 - acc: 0.9931 - val_loss: 0.8058 - val_acc: 0.8333
#
# Epoch 00137: val_acc did not improve from 0.88889
# Epoch 138/200
# 144/144 [==============================] - 0s 667us/step - loss: 0.0315 - acc: 1.0000 - val_loss: 0.8045 - val_acc: 0.8333
#
# Epoch 00138: val_acc did not improve from 0.88889
# Epoch 139/200
# 144/144 [==============================] - 0s 894us/step - loss: 0.0385 - acc: 1.0000 - val_loss: 0.8335 - val_acc: 0.8333
#
# Epoch 00139: val_acc did not improve from 0.88889
# Epoch 140/200
# 144/144 [==============================] - 0s 792us/step - loss: 0.0256 - acc: 1.0000 - val_loss: 0.8481 - val_acc: 0.8333
#
# Epoch 00140: val_acc did not improve from 0.88889
# Epoch 141/200
# 144/144 [==============================] - 0s 962us/step - loss: 0.0414 - acc: 0.9757 - val_loss: 0.8718 - val_acc: 0.8333
#
# Epoch 00141: val_acc did not improve from 0.88889
# Epoch 142/200
# 144/144 [==============================] - 0s 991us/step - loss: 0.0251 - acc: 0.9931 - val_loss: 0.8879 - val_acc: 0.8611
#
# Epoch 00142: val_acc did not improve from 0.88889
# Epoch 143/200
# 144/144 [==============================] - 0s 917us/step - loss: 0.0290 - acc: 0.9931 - val_loss: 0.9022 - val_acc: 0.8611
#
# Epoch 00143: val_acc did not improve from 0.88889
# Epoch 144/200
# 144/144 [==============================] - 0s 590us/step - loss: 0.0322 - acc: 0.9931 - val_loss: 0.8751 - val_acc: 0.8611
#
# Epoch 00144: val_acc did not improve from 0.88889
# Epoch 145/200
# 144/144 [==============================] - 0s 571us/step - loss: 0.0471 - acc: 0.9896 - val_loss: 0.8454 - val_acc: 0.8611
#
# Epoch 00145: val_acc did not improve from 0.88889
# Epoch 146/200
# 144/144 [==============================] - 0s 859us/step - loss: 0.0354 - acc: 0.9896 - val_loss: 0.8358 - val_acc: 0.8611
#
# Epoch 00146: val_acc did not improve from 0.88889
# Epoch 147/200
# 144/144 [==============================] - 0s 738us/step - loss: 0.0443 - acc: 0.9792 - val_loss: 0.8494 - val_acc: 0.8333
#
# Epoch 00147: val_acc did not improve from 0.88889
# Epoch 148/200
# 144/144 [==============================] - 0s 682us/step - loss: 0.0444 - acc: 0.9931 - val_loss: 0.8522 - val_acc: 0.8333
#
# Epoch 00148: val_acc did not improve from 0.88889
# Epoch 149/200
# 144/144 [==============================] - 0s 908us/step - loss: 0.0538 - acc: 0.9722 - val_loss: 0.8113 - val_acc: 0.8333
#
# Epoch 00149: val_acc did not improve from 0.88889
# Epoch 150/200
# 144/144 [==============================] - 0s 666us/step - loss: 0.0285 - acc: 0.9861 - val_loss: 0.7899 - val_acc: 0.8333
#
# Epoch 00150: val_acc did not improve from 0.88889
# Epoch 151/200
# 144/144 [==============================] - 0s 918us/step - loss: 0.0404 - acc: 0.9792 - val_loss: 0.8162 - val_acc: 0.8333
#
# Epoch 00151: val_acc did not improve from 0.88889
# Epoch 152/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0386 - acc: 0.9861 - val_loss: 0.8372 - val_acc: 0.8333
#
# Epoch 00152: val_acc did not improve from 0.88889
# Epoch 153/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0499 - acc: 0.9826 - val_loss: 0.8813 - val_acc: 0.8472
#
# Epoch 00153: val_acc did not improve from 0.88889
# Epoch 154/200
# 144/144 [==============================] - 0s 895us/step - loss: 0.0304 - acc: 1.0000 - val_loss: 0.8940 - val_acc: 0.8472
#
# Epoch 00154: val_acc did not improve from 0.88889
# Epoch 155/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0335 - acc: 1.0000 - val_loss: 0.8841 - val_acc: 0.8472
#
# Epoch 00155: val_acc did not improve from 0.88889
# Epoch 156/200
# 144/144 [==============================] - 0s 930us/step - loss: 0.0340 - acc: 0.9931 - val_loss: 0.9042 - val_acc: 0.8472
#
# Epoch 00156: val_acc did not improve from 0.88889
# Epoch 157/200
# 144/144 [==============================] - 0s 850us/step - loss: 0.0488 - acc: 0.9792 - val_loss: 0.8808 - val_acc: 0.8333
#
# Epoch 00157: val_acc did not improve from 0.88889
# Epoch 158/200
# 144/144 [==============================] - 0s 880us/step - loss: 0.0233 - acc: 0.9965 - val_loss: 0.8659 - val_acc: 0.8333
#
# Epoch 00158: val_acc did not improve from 0.88889
# Epoch 159/200
# 144/144 [==============================] - 0s 789us/step - loss: 0.0225 - acc: 0.9965 - val_loss: 0.8759 - val_acc: 0.8333
#
# Epoch 00159: val_acc did not improve from 0.88889
# Epoch 160/200
# 144/144 [==============================] - 0s 750us/step - loss: 0.0346 - acc: 0.9931 - val_loss: 0.8855 - val_acc: 0.8333
#
# Epoch 00160: val_acc did not improve from 0.88889
# Epoch 161/200
# 144/144 [==============================] - 0s 828us/step - loss: 0.0221 - acc: 1.0000 - val_loss: 0.9046 - val_acc: 0.8611
#
# Epoch 00161: val_acc did not improve from 0.88889
# Epoch 162/200
# 144/144 [==============================] - 0s 837us/step - loss: 0.0135 - acc: 1.0000 - val_loss: 0.9206 - val_acc: 0.8333
#
# Epoch 00162: val_acc did not improve from 0.88889
# Epoch 163/200
# 144/144 [==============================] - 0s 871us/step - loss: 0.0165 - acc: 1.0000 - val_loss: 0.9186 - val_acc: 0.8333
#
# Epoch 00163: val_acc did not improve from 0.88889
# Epoch 164/200
# 144/144 [==============================] - 0s 974us/step - loss: 0.0305 - acc: 0.9896 - val_loss: 0.8900 - val_acc: 0.8472
#
# Epoch 00164: val_acc did not improve from 0.88889
# Epoch 165/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0304 - acc: 0.9931 - val_loss: 0.8778 - val_acc: 0.8472
#
# Epoch 00165: val_acc did not improve from 0.88889
# Epoch 166/200
# 144/144 [==============================] - 0s 914us/step - loss: 0.0456 - acc: 0.9931 - val_loss: 0.8496 - val_acc: 0.8611
#
# Epoch 00166: val_acc did not improve from 0.88889
# Epoch 167/200
# 144/144 [==============================] - 0s 874us/step - loss: 0.0189 - acc: 1.0000 - val_loss: 0.8398 - val_acc: 0.8611
#
# Epoch 00167: val_acc did not improve from 0.88889
# Epoch 168/200
# 144/144 [==============================] - 0s 915us/step - loss: 0.0287 - acc: 0.9931 - val_loss: 0.8402 - val_acc: 0.8611
#
# Epoch 00168: val_acc did not improve from 0.88889
# Epoch 169/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0325 - acc: 0.9965 - val_loss: 0.8600 - val_acc: 0.8611
#
# Epoch 00169: val_acc did not improve from 0.88889
# Epoch 170/200
# 144/144 [==============================] - 0s 897us/step - loss: 0.0264 - acc: 0.9965 - val_loss: 0.8754 - val_acc: 0.8611
#
# Epoch 00170: val_acc did not improve from 0.88889
# Epoch 171/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0162 - acc: 1.0000 - val_loss: 0.8882 - val_acc: 0.8611
#
# Epoch 00171: val_acc did not improve from 0.88889
# Epoch 172/200
# 144/144 [==============================] - 0s 968us/step - loss: 0.0194 - acc: 1.0000 - val_loss: 0.8976 - val_acc: 0.8611
#
# Epoch 00172: val_acc did not improve from 0.88889
# Epoch 173/200
# 144/144 [==============================] - 0s 938us/step - loss: 0.0255 - acc: 0.9965 - val_loss: 0.9036 - val_acc: 0.8611
#
# Epoch 00173: val_acc did not improve from 0.88889
# Epoch 174/200
# 144/144 [==============================] - 0s 883us/step - loss: 0.0133 - acc: 1.0000 - val_loss: 0.9122 - val_acc: 0.8611
# Epoch 00174: val_acc did not improve from 0.88889
# Epoch 175/200
# 144/144 [==============================] - 0s 724us/step - loss: 0.0339 - acc: 0.9931 - val_loss: 0.9186 - val_acc: 0.8472
#
# Epoch 00175: val_acc did not improve from 0.88889
# Epoch 176/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0266 - acc: 0.9965 - val_loss: 0.9186 - val_acc: 0.8611
#
# Epoch 00176: val_acc did not improve from 0.88889
# Epoch 177/200
# 144/144 [==============================] - 0s 933us/step - loss: 0.0144 - acc: 1.0000 - val_loss: 0.9250 - val_acc: 0.8611
#
# Epoch 00177: val_acc did not improve from 0.88889
# Epoch 178/200
# 144/144 [==============================] - 0s 931us/step - loss: 0.0161 - acc: 1.0000 - val_loss: 0.9344 - val_acc: 0.8611
#
# Epoch 00178: val_acc did not improve from 0.88889
# Epoch 179/200
# 144/144 [==============================] - 0s 863us/step - loss: 0.0187 - acc: 0.9931 - val_loss: 0.9604 - val_acc: 0.8472
#
# Epoch 00179: val_acc did not improve from 0.88889
# Epoch 180/200
# 144/144 [==============================] - 0s 903us/step - loss: 0.0173 - acc: 0.9965 - val_loss: 0.9674 - val_acc: 0.8472
#
# Epoch 00180: val_acc did not improve from 0.88889
# Epoch 181/200
# 144/144 [==============================] - 0s 720us/step - loss: 0.0230 - acc: 0.9931 - val_loss: 0.9536 - val_acc: 0.8472
#
# Epoch 00181: val_acc did not improve from 0.88889
# Epoch 182/200
# 144/144 [==============================] - 0s 650us/step - loss: 0.0119 - acc: 1.0000 - val_loss: 0.9043 - val_acc: 0.8611
#
# Epoch 00182: val_acc did not improve from 0.88889
# Epoch 183/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0365 - acc: 0.9792 - val_loss: 0.9148 - val_acc: 0.8611
#
# Epoch 00183: val_acc did not improve from 0.88889
# Epoch 184/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0213 - acc: 0.9931 - val_loss: 0.9352 - val_acc: 0.8333
#
# Epoch 00184: val_acc did not improve from 0.88889
# Epoch 185/200
# 144/144 [==============================] - 0s 886us/step - loss: 0.0576 - acc: 0.9688 - val_loss: 0.9128 - val_acc: 0.8472
#
# Epoch 00185: val_acc did not improve from 0.88889
# Epoch 186/200
# 144/144 [==============================] - 0s 911us/step - loss: 0.0596 - acc: 0.9757 - val_loss: 0.9438 - val_acc: 0.8472
#
# Epoch 00186: val_acc did not improve from 0.88889
# Epoch 187/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0242 - acc: 0.9931 - val_loss: 1.0163 - val_acc: 0.8194
#
# Epoch 00187: val_acc did not improve from 0.88889
# Epoch 188/200
# 144/144 [==============================] - 0s 917us/step - loss: 0.0249 - acc: 0.9965 - val_loss: 1.0528 - val_acc: 0.8056
#
# Epoch 00188: val_acc did not improve from 0.88889
# Epoch 189/200
# 144/144 [==============================] - 0s 909us/step - loss: 0.0163 - acc: 1.0000 - val_loss: 1.0465 - val_acc: 0.8056
#
# Epoch 00189: val_acc did not improve from 0.88889
# Epoch 190/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0261 - acc: 0.9861 - val_loss: 1.0296 - val_acc: 0.8333
#
# Epoch 00190: val_acc did not improve from 0.88889
# Epoch 191/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0112 - acc: 1.0000 - val_loss: 1.0039 - val_acc: 0.8333
#
# Epoch 00191: val_acc did not improve from 0.88889
# Epoch 192/200
# 144/144 [==============================] - 0s 814us/step - loss: 0.0183 - acc: 0.9931 - val_loss: 0.9797 - val_acc: 0.8472
#
# Epoch 00192: val_acc did not improve from 0.88889
# Epoch 193/200
# 144/144 [==============================] - 0s 786us/step - loss: 0.0300 - acc: 0.9896 - val_loss: 0.9672 - val_acc: 0.8472
#
# Epoch 00193: val_acc did not improve from 0.88889
# Epoch 194/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0228 - acc: 0.9965 - val_loss: 0.9542 - val_acc: 0.8472
#
# Epoch 00194: val_acc did not improve from 0.88889
# Epoch 195/200
# 144/144 [==============================] - 0s 981us/step - loss: 0.0248 - acc: 0.9931 - val_loss: 0.9493 - val_acc: 0.8472
#
# Epoch 00195: val_acc did not improve from 0.88889
# Epoch 196/200
# 144/144 [==============================] - 0s 1ms/step - loss: 0.0192 - acc: 1.0000 - val_loss: 0.9504 - val_acc: 0.8333
#
# Epoch 00196: val_acc did not improve from 0.88889
# Epoch 197/200
# 144/144 [==============================] - 0s 974us/step - loss: 0.0166 - acc: 0.9931 - val_loss: 0.9431 - val_acc: 0.8472
#
# Epoch 00197: val_acc did not improve from 0.88889
# Epoch 198/200
# 144/144 [==============================] - 0s 994us/step - loss: 0.0351 - acc: 0.9931 - val_loss: 0.9469 - val_acc: 0.8333
#
# Epoch 00198: val_acc did not improve from 0.88889
# Epoch 199/200
# 144/144 [==============================] - 0s 939us/step - loss: 0.0116 - acc: 1.0000 - val_loss: 0.9557 - val_acc: 0.8333
#
# Epoch 00199: val_acc did not improve from 0.88889
# Epoch 200/200
# 144/144 [==============================] - 0s 655us/step - loss: 0.0148 - acc: 1.0000 - val_loss: 0.9484 - val_acc: 0.8333
#
# Epoch 00200: val_acc did not improve from 0.88889
# Loss function: binary_crossentropy

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_97 (Dense)             (None, 100)               1500
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 11,802
# Trainable params: 11,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# # 6. Analysis of the performance

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['Training accuracy','Validation accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()
plt.ylim(0.7,1.02)
plt.show()

# %%
my_model = load_model('best_model.hdf5')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

y_pred=np.argmax(my_model.predict(X_test),axis=1)

print(confusion_matrix(y_test,y_pred))

print(classification_report(y_test,y_pred))
# Out:
# [[16  4]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89        20
#            1       0.80      1.00      0.89        16
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.90      0.89        36
# weighted avg       0.91      0.89      0.89        36

# %%
print('Maximum validation accuracy',round(np.max(history.history['val_acc']),2))
# Out:
# Maximum validation accuracy 0.89
